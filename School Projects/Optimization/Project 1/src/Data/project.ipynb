# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt

# Load data from CSV files
population_df = pd.read_csv('population.csv')
employment_rate_df = pd.read_csv('employment_rate.csv')
avg_income_df = pd.read_csv('avg_individual_income.csv')
child_care_df = pd.read_csv('child_care_regulated.csv')
potential_locations_df = pd.read_csv('potential_locations.csv')

# Preview the data
print("Population Data:\n", population_df.head())
print("Employment Rate Data:\n", employment_rate_df.head())
print("Average Income Data:\n", avg_income_df.head())
print("Child Care Facilities Data:\n", child_care_df.head())
print("Potential Locations Data:\n", potential_locations_df.head())
# Out:
# Population Data:
#     zipcode  Total    -5   5-9  10-14  15-19  20-24  25-29  30-34  35-39  \
# 0     6390     53     0     1      5      0      6      0      9     18
# 1    10001  27004   744   784    942   1035   2296   3806   3588   2524
# 2    10002  76518  2142  3046   3198   2652   4528   6988   6278   5157
# 3    10003  53877  1440  1034    953   7013   6344   7100   6427   3221
# 4    10004   4579   433   182    161    108    109    601    724    490
#
#    40-44  45-49  50-54  55-59  60-64  65-69  70-74  75-79  80-84   85+
# 0      0     12      2      0      0      0      0      0      0     0
# 1   1702   1903   1704   1225   1323    933    815    616    488   576
# 2   4962   4822   4410   6106   4548   4815   4748   2531   2793  2794
# 3   2907   1988   2698   2350   2274   2793   1854   1646    779  1056
# 4    241    313    549    279    199    173      2     15      0     0
# Employment Rate Data:
#     zipcode  employment rate
# 0    10001         0.595097
# ...
