# %%
import pandas as pd
import numpy as np
import gurobipy as grb
from haversine import haversine, Unit

# %%
df_income = pd.read_csv("./Data/income.csv")
df_care = pd.read_csv("./Data/child_care.csv")
df_employment = pd.read_csv("./Data/employment.csv")
df_population = pd.read_csv("./Data/population.csv")
df_locations = pd.read_csv("./Data/potential_loc.csv")

# %%
## The data set of population of children

df_children = df_population.loc[:, ['zip_code', '-5', '5-9', '10-14']]

## Calculate population in each group
df_children['0-14'] = df_children['-5'] + df_children['5-9'] + df_children['10-14']
df_children['population_total'] = ((13 / 15) * df_children['0-14']).astype(int)
df_children['population_5-12'] = df_children['population_total'] - df_children['-5']
df_children = df_children.drop(['5-9', '10-14', '0-14'], axis = 1).rename({'-5': 'population_0-5'}, axis = 1)

# %%
df_locations
# Out:
#         zip_code   latitude  longitude
# 0          10001  40.741893 -74.000140
# 1          10001  40.752007 -74.005436
# 2          10001  40.750545 -73.997147
# 3          10001  40.744080 -74.001932
# 4          10001  40.748690 -73.999341
# ...          ...        ...        ...
# 102295     14806  42.155072 -77.788830
# 102296     14806  42.157253 -77.785814
# 102297     14806  42.161653 -77.783166
# 102298     14806  42.158862 -77.789563
# 102299     14806  42.148457 -77.799503
#
# [102300 rows x 3 columns]

# %%
## The demographical data of each region
df_demo = pd.merge(left = df_income, right = df_employment, how = "left", on = "zip_code").merge(df_children, on = "zip_code")

## Identify high demand regions
df_demo['high demand'] = ((df_demo['average income'] > 60000) * (df_demo['employment rate'] > 0.6)).astype(int)

# %%
df_care
# Out:
#        zip_code  facility_id program_type facility_status  \
# 0         10001       837597         SACC    Registration
# 1         10001       661697         GFDC         License
# 2         10001       837329         SACC    Registration
# 3         10001       350076          FDC    Registration
# 4         10001       292419         SACC    Registration
# ...         ...          ...          ...             ...
# 14751     14770       115279         SACC    Registration
# 14752     14772       782407         SACC    Registration
# 14753     14772       888218         GFDC         License
# 14754     14805       866946          FDC    Registration
# 14755     14806        22363         GFDC         License
#
#                                            facility_name       city  \
# 0                              I Have a Dream Foundation   New York
# 1                         Chelsea Little Angels Day Care   New York
# 2                        Bright Horizons at Hudson Yards   New York
# 3                                          GRAMMAS HANDS   New York
# 4                          The Hudson Guild @26th Street   New York
# ...                                                  ...        ...
# 14751  Young Men's Christian Association of Olean NY ...  Portville
# 14752                              The Relief Zone, Inc.   Randolph
# 14753                              Main Street Munchkins   Randolph
# 14754                            Alpine Children's House     Alpine
# 14755       The Little Children Day Care Center (T.L.C.)    Andover
#
#       school_district_name  infant_capacity  toddler_capacity  \
# 0              Manhattan 2                0                 0
# 1              Manhattan 2                0                 0
# 2              Manhattan 2                0                 0
# 3              Manhattan 2                0                 0
# 4              Manhattan 2                0                 0
# ...                    ...              ...               ...
# 14751            Portville                0                 0
# 14752             Randolph                0                 0
# 14753             Randolph                0                 0
# 14754          Trumansburg                0                 0
# 14755              Andover                0                 0
#
#        preschool_capacity  school_age_capacity  children_capacity  \
# 0                       0                   84                  0
# 1                       0                    4                 12
# 2                       0                   17                  0
# 3                       0                    2                  6
# 4                       0                   79                  0
# ...                   ...                  ...                ...
# 14751                  15                   55                  0
# 14752                  32                   60                  0
# 14753                   0                    4                 12
# 14754                   0                    2                  6
# 14755                   0                    4                 12
#
#        total_capacity   latitude  longitude
# 0                  84  40.748836 -73.999810
# 1                  16  40.748911 -74.001546
# 2                  17  40.752093 -74.002588
# 3                   8  40.748296 -74.001263
# 4                  79  40.749247 -74.001598
# ...               ...        ...        ...
# 14751              70  42.034147 -78.331101
# 14752              92  42.164507 -78.966681
# 14753              16  42.163749 -78.968019
# 14754               8        NaN        NaN
# 14755              16  42.155719 -77.795484
#
# [14756 rows x 15 columns]

# %%
## Get current capacity
## Can add latitude and longitude to include coordinates
df_care["current_0-5"] = (df_care['infant_capacity'] 
                              + df_care['toddler_capacity'] 
                              + df_care['preschool_capacity'] 
                              + (5/12) * df_care['children_capacity']
                             ).astype(int)

df_care["current_5-12"] = (df_care['total_capacity'] - df_care['current_0-5']).astype(int)

# %%
df_current = df_care.loc[:, ["zip_code", "current_0-5", "current_5-12", "total_capacity", 'latitude', 'longitude']]

## For existing facilities with 0 capacity, we cannot estimate the cost of expanding, thus we drop them
df_current = df_current.where(df_current['total_capacity'] != 0).dropna()

"""
df_temp = df_current.merge(df_current['zip_code'].value_counts().rename("count"), right_index = True, left_on = "zip_code")

counts = df_temp['count'].to_list()
curr_idx = 0
curr_count = counts[0]\
n = len(counts)
new_idx = []

for i in range(n):
    if curr_idx == curr_count:
        curr_count = counts[i]
        curr_idx = 0
    
    new_idx.append(curr_idx)
    curr_idx += 1

new_facility_idx = pd.Series(new_idx, name = "new_id")
df_current = df_current.merge(new_facility_idx, how = "left", left_index = True, right_index = True).fillna(0).astype(int)
"""

## Get the upper bound for x + y, if total_capacity > 500, then set the upper bound to 0
df_current['upper_bound'] = 500 - df_current['total_capacity']
df_current['upper_bound'] = df_current['upper_bound'].where(df_current['upper_bound'] > 0).fillna(0).astype(int)
df_current
# Out:
#        zip_code  current_0-5  current_5-12  total_capacity   latitude  \
# 0       10001.0          0.0          84.0            84.0  40.748836
# 1       10001.0          5.0          11.0            16.0  40.748911
# 2       10001.0          0.0          17.0            17.0  40.752093
# 3       10001.0          2.0           6.0             8.0  40.748296
# 4       10001.0          0.0          79.0            79.0  40.749247
# ...         ...          ...           ...             ...        ...
# 14750   14767.0          5.0          11.0            16.0  42.072116
# 14751   14770.0         15.0          55.0            70.0  42.034147
# 14752   14772.0         32.0          60.0            92.0  42.164507
# 14753   14772.0          5.0          11.0            16.0  42.163749
# 14755   14806.0          5.0          11.0            16.0  42.155719
#
#        longitude  upper_bound
# 0     -73.999810          416
# 1     -74.001546          484
# 2     -74.002588          483
# 3     -74.001263          492
# 4     -74.001598          421
# ...          ...          ...
# 14750 -79.482498          484
# 14751 -78.331101          430
# 14752 -78.966681          408
# 14753 -78.968019          484
# 14755 -77.795484          484
#
# [14227 rows x 7 columns]

# %%
## Create the whole data set, containing demographical data, current capacities and requirements by constraints
df_current_capacity = df_current.groupby("zip_code")[["current_0-5", "current_5-12"]].sum().reset_index()
df_main = df_demo.merge(df_current_capacity, on = "zip_code")

## How many 0-5 slots are needed to meet 2/3 population of 0-5 children
df_main['demand_policy'] = (2 * df_main['population_0-5'] / 3).astype(int)

## How many 0-5 slots should be created to meet 2/3 population of 0-5 children
df_main['gap_policy'] = df_main['demand_policy'] - df_main["current_0-5"]

## How many slots are needed to make sure this region not classified as child care desert
df_main['demand_not_desert'] = df_main.apply(
    lambda x: int(x['population_total'] / 2) if x['high demand'] else int(x['population_total'] / 3), 
    axis = 1
)

## How many slots should be created to eliminate child care deserts
df_main['gap_not_desert'] = df_main['demand_not_desert'] - df_main['demand_policy'] - df_main['current_5-12']

## If the gap is negaives, it means no new slots are needed, thus set to 0
df_main['gap_not_desert'] = df_main['gap_not_desert'].where(df_main['gap_not_desert'] > 0).fillna(0)

df_main = df_main.drop(["average income", "employment rate"], axis = 1)\
                 .set_index("zip_code")\
                 .astype(int)
df_main
# Out:
#           population_0-5  population_total  population_5-12  high demand  \
# zip_code
# 10001                744              2140             1396            0
# 10002               2142              7267             5125            0
# 10003               1440              2970             1530            0
# 10004                433               672              239            0
# 10005                484               794              310            1
# ...                  ...               ...              ...          ...
# 14747                156               362              206            0
# 14767                101               422              321            0
# 14770                137               482              345            0
# 14772                256               635              379            0
# 14806                127               339              212            0
#
#           current_0-5  current_5-12  demand_policy  gap_policy  \
# zip_code
# 10001               9           600            496         487
# 10002              93          4628           1428        1335
# 10003               0          1995            960         960
# 10004               0           263            288         288
# 10005               0            39            322         322
# ...               ...           ...            ...         ...
# 14747               4            11            104         100
# 14767               5            11             67          62
# 14770              15            55             91          76
# 14772              37            71            170         133
# 14806               5            11             84          79
#
#           demand_not_desert  gap_not_desert
# zip_code
# 10001                   713               0
# 10002                  2422               0
# 10003                   990               0
# 10004                   224               0
# 10005                   397              36
# ...                     ...             ...
# 14747                   120               5
# 14767                   140              62
# 14770                   160              14
# 14772                   211               0
# 14806                   113              18
#
# [1007 rows x 10 columns]

# %%
# part 2

# %%
## Set of zip codes
zip_codes = df_main.index.to_list()

## Set of constraints. type = dict, with zip codes as keys
gap_policy = df_main['gap_policy'].to_dict()
gap_not_desert = df_main['gap_not_desert'].to_dict()

## Set of constants, type = dict, with zip codes as keys
num_facilities = df_current['zip_code'].value_counts().sort_index().to_dict()           ## Number of existing facilities in each region
capacities = df_current.groupby("zip_code")['total_capacity'].apply(list).to_dict()     ## Capacities of existing facilities, categorized by zip codes
upper_bounds = df_current.groupby("zip_code")['upper_bound'].apply(list).to_dict()      ## Upper bounds of x + y

decision_varsX = {k: [0] * v for k, v in num_facilities.items()}        ## Decision variables: x
decision_varsY = {k: [0] * v for k, v in num_facilities.items()}        ## Decision variables: y

decision_varsS = {z: [] for z in zip_codes}                             ## Decision variables: s
decision_varsM = {z: [] for z in zip_codes}                             ## Decision variables: m
decision_varsL = {z: [] for z in zip_codes}                             ## Decision variables: l

# %%
import pickle
import numpy as np
import pandas as pd
from haversine import haversine, Unit
import os

distance_threshold = 0.06  # 0.06 miles

# Set this to True if you want to save as an Excel file as well
save_as_xlsx = True  

# Define paths for pickle and Excel files
pickle_path = 'distance_matrices.pkl'
excel_path = 'distance_matrices.xlsx'

# Initialize dictionaries to hold distance matrices
dist_existing_new = {}
dist_new_new = {}

# Check if the pickle file exists
if os.path.exists(pickle_path):
    # Load data from the pickle file
    with open(pickle_path, 'rb') as f:
        distance_data = pickle.load(f)
        
        # Ensure keys exist in the pickle data
        dist_existing_new = distance_data.get('existing_new', {})
        dist_new_new = distance_data.get('new_new', {})

    if dist_existing_new and dist_new_new:
        print("Loaded distance matrices from pickle file.")
    else:
        print("Error: Missing expected keys in pickle file. Loading from Excel instead if available.")
        # Continue to check Excel or create if necessary

# If no pickle file, check for the Excel file
elif os.path.exists(excel_path):
    # Load data from the Excel file and convert to numpy arrays
    xls = pd.ExcelFile(excel_path)
    for i in zip_codes:
        df_existing_new = pd.read_excel(xls, sheet_name=f'existing_new_{i}')
        df_new_new = pd.read_excel(xls, sheet_name=f'new_new_{i}')
        
        dist_existing_new[i] = df_existing_new.values
        dist_new_new[i] = df_new_new.values

    # Save the loaded data to a pickle file for future use
    with open(pickle_path, 'wb') as f:
        pickle.dump({'existing_new': dist_existing_new, 'new_new': dist_new_new}, f)
    print("Loaded distance matrices from Excel and saved to pickle file.")

# If neither pickle nor Excel file exists, create distance matrices
else:
    for i in zip_codes:
        # Extract coordinates for existing and new facilities
        existing_locations = df_current[df_current['zip_code'] == i][['latitude', 'longitude']].values
        new_locations = df_locations[df_locations['zip_code'] == i][['latitude', 'longitude']].values

        # Create distance matrix for existing vs new facilities
        dist_existing_new[i] = np.zeros((num_facilities[i], 100))
        for j in range(num_facilities[i]):
            loc1 = (existing_locations[j][0], existing_locations[j][1])
            for k in range(100):
                loc2 = (new_locations[k][0], new_locations[k][1])
                dist_existing_new[i][j, k] = haversine(loc1, loc2, unit=Unit.MILES)

        # Create distance matrix for new vs new facilities
        dist_new_new[i] = np.zeros((100, 100))
        for k1 in range(100):
            loc1 = (new_locations[k1][0], new_locations[k1][1])
            for k2 in range(k1 + 1, 100):
                loc2 = (new_locations[k2][0], new_locations[k2][1])
                dist_new_new[i][k1, k2] = haversine(loc1, loc2, unit=Unit.MILES)
                dist_new_new[i][k2, k1] = dist_new_new[i][k1, k2]  # Symmetric

    # Save the distance matrices to pickle
    with open(pickle_path, 'wb') as f:
        pickle.dump({'existing_new': dist_existing_new, 'new_new': dist_new_new}, f)
    print("Created and saved distance matrices to 'distance_matrices.pkl'.")

    # Optionally save distance matrices to Excel
    if save_as_xlsx:
        with pd.ExcelWriter(excel_path) as writer:
            for i in zip_codes:
                df_existing_new = pd.DataFrame(dist_existing_new[i])
                df_new_new = pd.DataFrame(dist_new_new[i])

                df_existing_new.to_excel(writer, sheet_name=f'existing_new_{i}', index=False)
                df_new_new.to_excel(writer, sheet_name=f'new_new_{i}', index=False)
                print(f"Saved matrices for zip code: {i} to Excel.")
# Out:
# Loaded distance matrices from pickle file.

# %%
from gurobipy import Model, GRB, quicksum

model_pt2 = Model(name="Part2")

# Set of zip codes
zip_codes = df_main.index.to_list()

# Parameters
gap_policy = df_main['gap_policy'].to_dict()
gap_not_desert = df_main['gap_not_desert'].to_dict()
num_facilities = df_current['zip_code'].value_counts().sort_index().to_dict()
capacities = df_current.groupby("zip_code")['total_capacity'].apply(list).to_dict()
upper_bounds = df_current.groupby("zip_code")['upper_bound'].apply(list).to_dict()

# Decision Variables for Expansion
decision_varsX = {k: [None] * v for k, v in num_facilities.items()}
decision_varsY = {k: [None] * v for k, v in num_facilities.items()}

# Decision Variables for New Facilities
decision_varsS = {z: [] for z in zip_codes}
decision_varsM = {z: [] for z in zip_codes}
decision_varsL = {z: [] for z in zip_codes}

# Define decision variables for existing facilities
for z in zip_codes:
    num_facs = num_facilities[z]
    decision_varsX[z], decision_varsY[z] = [None] * num_facs, [None] * num_facs
    for j in range(num_facs):
        x_temp = model_pt2.addVar(lb=0, vtype=GRB.INTEGER, name=f"X_{z}_{j}")
        y_temp = model_pt2.addVar(lb=0, vtype=GRB.INTEGER, name=f"Y_{z}_{j}")
        decision_varsX[z][j] = x_temp
        decision_varsY[z][j] = y_temp

# Variables for new facilities, with small (S), medium (M), and large (L) options
for z in zip_codes:
    for k in range(100):
        s_temp = model_pt2.addVar(lb=0, ub=1, vtype=GRB.BINARY, name=f"S_{z}_{k}")
        m_temp = model_pt2.addVar(lb=0, ub=1, vtype=GRB.BINARY, name=f"M_{z}_{k}")
        l_temp = model_pt2.addVar(lb=0, ub=1, vtype=GRB.BINARY, name=f"L_{z}_{k}")
        decision_varsS[z].append(s_temp)
        decision_varsM[z].append(m_temp)
        decision_varsL[z].append(l_temp)

# Update model
model_pt2.update()

# %%
# Define piecewise variables for each facility
delta1 = {i: [model_pt2.addVar(lb=0, vtype=GRB.CONTINUOUS, name=f"delta1_{i}_{j}") for j in range(num_facilities[i])] for i in zip_codes}
delta2 = {i: [model_pt2.addVar(lb=0, vtype=GRB.CONTINUOUS, name=f"delta2_{i}_{j}") for j in range(num_facilities[i])] for i in zip_codes}
delta3 = {i: [model_pt2.addVar(lb=0, vtype=GRB.CONTINUOUS, name=f"delta3_{i}_{j}") for j in range(num_facilities[i])] for i in zip_codes}

# Define binary variables to indicate if each tier is active
is_tier1_active = {i: [model_pt2.addVar(vtype=GRB.BINARY, name=f"is_tier1_active_{i}_{j}") for j in range(num_facilities[i])] for i in zip_codes}
is_tier2_active = {i: [model_pt2.addVar(vtype=GRB.BINARY, name=f"is_tier2_active_{i}_{j}") for j in range(num_facilities[i])] for i in zip_codes}
is_tier3_active = {i: [model_pt2.addVar(vtype=GRB.BINARY, name=f"is_tier3_active_{i}_{j}") for j in range(num_facilities[i])] for i in zip_codes}

# Constraints for Piecewise Segments
M = 1000000000  # Big M constant
for i in zip_codes:
    for j in range(num_facilities[i]):
        # Upper bounds for each delta segment
        model_pt2.addConstr(delta1[i][j] <= 0.1 * capacities[i][j])
        model_pt2.addConstr(delta2[i][j] <= 0.05 * capacities[i][j])
        model_pt2.addConstr(delta3[i][j] <= 0.05 * capacities[i][j])

        # Total expansion equals the sum of piecewise increments
        model_pt2.addConstr(delta1[i][j] + delta2[i][j] + delta3[i][j] == decision_varsX[i][j] + decision_varsY[i][j])

        # Link delta variables to binary indicators
        model_pt2.addConstr(delta1[i][j] <= M * is_tier1_active[i][j])
        model_pt2.addConstr(delta2[i][j] <= M * is_tier2_active[i][j])
        model_pt2.addConstr(delta3[i][j] <= M * is_tier3_active[i][j])

        # Ensure binary variables are activated only when corresponding delta is positive
        model_pt2.addConstr(is_tier1_active[i][j] + is_tier2_active[i][j] + is_tier3_active[i][j] <= 1)

# Objective Function with Piecewise Cost Model
model_pt2.setObjective(
    quicksum(
        sum(
            # Baseline costs for each tier based on binary activation variables
            (20000 * is_tier1_active[i][j] + 200 * capacities[i][j] * delta1[i][j] +
             400 * capacities[i][j] * delta2[i][j] +
             1000 * capacities[i][j] * delta3[i][j] +
             100 * decision_varsX[i][j])  # Additional cost per slot for ages 0-5
            for j in range(num_facilities[i])
        ) for i in zip_codes
    ) +
    quicksum(
        sum(
            65000 * decision_varsS[i][k] + 95000 * decision_varsM[i][k] + 115000 * decision_varsL[i][k]
            for k in range(100)
        ) for i in zip_codes
    ),
    GRB.MINIMIZE
)

# %%
# Capacity constraints based on policy gaps
model_pt2.addConstrs(
    (grb.quicksum(decision_varsX[i]) +
     grb.quicksum(50 * decision_varsS[i][k] + 100 * decision_varsM[i][k] + 200 * decision_varsL[i][k] for k in range(100))
     >= gap_policy[i] for i in zip_codes),
    name="policy"
)

# Constraints for no desert regions
model_pt2.addConstrs(
    (grb.quicksum(decision_varsX[i]) + grb.quicksum(decision_varsY[i]) +
     grb.quicksum(100 * decision_varsS[i][k] + 200 * decision_varsM[i][k] + 400 * decision_varsL[i][k] for k in range(100))
     >= gap_not_desert[i] for i in zip_codes),
    name="not_desert"
)

# Constraints for expansion limits by facility
for z, l in num_facilities.items():
    model_pt2.addConstrs(
        (decision_varsX[z][j] + decision_varsY[z][j] <= upper_bounds[z][j] for j in range(l)),
        name="total_capacity"
    )
    model_pt2.addConstrs(
        (5 * (decision_varsX[z][j] + decision_varsY[z][j]) <= capacities[z][j] for j in range(l)),
        name="ratio"
    )
    
# Constraint: Only one new facility (small, medium, or large) can be built in each location
for i in zip_codes:
    for j in range(100):  # assuming there are up to 100 possible new facility locations per zip code
        model_pt2.addConstr(
            decision_varsS[i][j] + decision_varsM[i][j] + decision_varsL[i][j] <= 1,
            name=f"one_facility_per_location_{i}_{j}"
        )

# Distance limitations for new and existing facilities
for z in zip_codes:
    existing_facs = len(dist_existing_new[z])
    new_facs = len(dist_new_new[z])

# Constraints between existing and new facilities
for i in range(existing_facs):
    for j in range(new_facs):
        if dist_existing_new[z][i, j] < 0.06:
            model_pt2.addConstr(
                 decision_varsS[z][j] + decision_varsM[z][j] + decision_varsL[z][j] == 0,
                 name=f"dist_existing_new_{z}_{i}_{j}"
            )

    # Constraints among new facilities
for i in range(new_facs):
    for j in range(i + 1, new_facs):
        if dist_new_new[z][i, j] < 0.06:
            model_pt2.addConstr(
                decision_varsS[z][i] + decision_varsM[z][i] + decision_varsL[z][i] +
                decision_varsS[z][j] + decision_varsM[z][j] + decision_varsL[z][j] <= 1,
                name=f"dist_new_new_{z}_{i}_{j}"
            )

# Solve the model
model_pt2.optimize()
# Check if the model found an optimal solution
if model_pt2.status == grb.GRB.OPTIMAL:
    for z in zip_codes:
        for j in range(num_facilities[z]):
            # Ensure decision_varsX and decision_varsY are Gurobi variables
            if decision_varsX[z][j].x > 0 or decision_varsY[z][j].x > 0:
                print(f"Expand facility in zip code {z}, facility {j}: X = {decision_varsX[z][j].x}, Y = {decision_varsY[z][j].x}")
        for k in range(100):
            # Print information for new facilities
            if decision_varsS[z][k].x > 0 or decision_varsM[z][k].x > 0 or decision_varsL[z][k].x > 0:
                print(f"New facility in zip code {z}, location {k}: Small = {decision_varsS[z][k].x}, Medium = {decision_varsM[z][k].x}, Large = {decision_varsL[z][k].x}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 245023 rows, 415916 columns and 1247979 nonzeros
# Model fingerprint: 0x681b6297
# Variable types: 42681 continuous, 373235 integer (344781 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+09]
#   Objective range  [1e+02, 9e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 8e+03]
# Warning: Model contains large matrix coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 4.350750e+08
# Presolve removed 107925 rows and 119945 columns (presolve time = 5s) ...
# Presolve removed 107925 rows and 143745 columns (presolve time = 10s) ...
# Presolve removed 159691 rows and 196905 columns (presolve time = 15s) ...
# Presolve removed 244757 rows and 415361 columns (presolve time = 49s) ...
# Presolve removed 244757 rows and 415361 columns
# Presolve time: 49.55s
# Presolved: 266 rows, 555 columns, 1155 nonzeros
# Found heuristic solution: objective 3.399389e+08
# Variable types: 108 continuous, 447 integer (373 binary)
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.3701890e+08   2.245625e+02   0.000000e+00     50s
#       40    3.3908487e+08   0.000000e+00   0.000000e+00     50s
#
# Root relaxation: objective 3.390849e+08, 40 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3.3908e+08    0    1 3.3994e+08 3.3908e+08  0.25%     -   50s
# H    0     0                    3.390889e+08 3.3908e+08  0.00%     -   50s
#
# Explored 1 nodes (40 simplex iterations) in 50.42 seconds (8.71 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 3.39089e+08 3.39939e+08 4.35075e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.390888998791e+08, best bound 3.390848749245e+08, gap 0.0012%
# New facility in zip code 10001, location 32: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10001, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10001, location 72: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10002, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10002, location 25: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10002, location 47: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10002, location 53: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10002, location 54: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10002, location 75: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10002, location 80: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10003, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10003, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10003, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10003, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10003, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10004, location 78: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10004, location 82: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10005, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10005, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10006, location 25: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10007, location 15: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10007, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10007, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10009, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10009, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10009, location 10: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10009, location 11: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10009, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10009, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10009, location 95: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10010, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10010, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10010, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10010, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10010, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10011, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10011, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10011, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10011, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# Expand facility in zip code 10012, facility 1: X = 1.0, Y = 0.0
# New facility in zip code 10012, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10012, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10013, location 16: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10013, location 65: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10013, location 76: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10013, location 79: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10013, location 91: Small = 0.0, Medium = 0.0, Large = 1.0
# Expand facility in zip code 10014, facility 3: X = 1.0, Y = 0.0
# New facility in zip code 10014, location 82: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10014, location 84: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10016, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10016, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10016, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10016, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10016, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10016, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10017, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10019, location 9: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10019, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10019, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10019, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10021, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10021, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10021, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10021, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10021, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10021, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10022, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10022, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10022, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10022, location 24: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10022, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10023, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10023, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10023, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10023, location 3: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10023, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10023, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10023, location 25: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10023, location 26: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10023, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10023, location 47: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10023, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10023, location 99: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 3: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 4: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 25: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 26: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 47: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10024, location 99: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 25: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 53: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 65: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10025, location 73: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10025, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10026, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10026, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10026, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10026, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10026, location 71: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10026, location 73: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10026, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10027, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10027, location 4: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10027, location 5: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10027, location 6: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10027, location 14: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10027, location 15: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10027, location 16: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10027, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10027, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10027, location 25: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10027, location 26: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10027, location 27: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10028, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10028, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10028, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10028, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10028, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10028, location 47: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10029, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10029, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10029, location 10: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10029, location 11: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10029, location 12: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10029, location 17: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10029, location 20: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10029, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10029, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10029, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10029, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10029, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10029, location 90: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10030, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10030, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10030, location 10: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10030, location 11: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10030, location 20: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10030, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10031, location 20: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10031, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10031, location 43: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10031, location 44: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10031, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10031, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10031, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10032, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10032, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10032, location 73: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10032, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10032, location 96: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10032, location 97: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10033, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10033, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10033, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10033, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10033, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10033, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10033, location 72: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10033, location 73: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10033, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10034, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10034, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10034, location 10: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10034, location 11: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10034, location 12: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10034, location 40: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10034, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10034, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10035, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10035, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10035, location 10: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10035, location 11: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10035, location 20: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10035, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10035, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10035, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10036, location 16: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10036, location 76: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10036, location 79: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10037, location 4: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10037, location 76: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10037, location 79: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10037, location 83: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10038, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10038, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10038, location 49: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10039, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10039, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10039, location 73: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10039, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10039, location 96: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10039, location 97: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10040, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10040, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10040, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10040, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10040, location 73: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10044, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10044, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10044, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10044, location 98: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10065, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10065, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10065, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10065, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10065, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10065, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10065, location 47: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10065, location 89: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10069, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10069, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10069, location 54: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10075, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10075, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10075, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10075, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10075, location 65: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10128, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10128, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10128, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10128, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10128, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10128, location 25: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10128, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10128, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10128, location 47: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10128, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10280, location 61: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10280, location 84: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10282, location 78: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10282, location 82: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10301, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10301, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10301, location 3: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10301, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10301, location 25: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10301, location 26: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10301, location 47: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10301, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10301, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10302, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10302, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10302, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10302, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10302, location 72: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10303, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10303, location 49: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10303, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10303, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10304, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10304, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10304, location 11: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10304, location 12: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10304, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10304, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10304, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10305, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10305, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10305, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10305, location 31: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10305, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10305, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10306, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10306, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10306, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10306, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10306, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10306, location 25: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10306, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10306, location 47: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10306, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10307, location 65: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10307, location 76: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10307, location 79: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10307, location 91: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10308, location 42: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10308, location 68: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10308, location 94: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10308, location 97: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10309, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10309, location 1: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10309, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10309, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10309, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10309, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10309, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10310, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10310, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10310, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10310, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10310, location 25: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10310, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10310, location 47: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10312, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10312, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10312, location 3: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10312, location 4: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10312, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10312, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10312, location 25: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10312, location 26: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10312, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10312, location 47: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10312, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10312, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 3: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 4: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 5: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 25: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 26: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 27: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 28: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10314, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 47: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 54: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10314, location 99: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10451, location 4: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10451, location 7: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10451, location 8: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10451, location 9: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10451, location 18: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10451, location 19: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10451, location 20: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10451, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10451, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10451, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10452, location 15: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10452, location 17: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10452, location 18: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10452, location 19: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10452, location 30: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10452, location 31: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10452, location 41: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10452, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10452, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10452, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10452, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10452, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10452, location 99: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10453, location 16: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10453, location 19: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10453, location 20: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10453, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10453, location 39: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10453, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10453, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10453, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10453, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10453, location 58: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10453, location 60: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10453, location 61: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10453, location 62: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10454, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10454, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10454, location 3: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10454, location 12: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10454, location 13: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10454, location 14: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10454, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10454, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10454, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10455, location 7: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10455, location 8: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10455, location 18: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10455, location 20: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10455, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10455, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10455, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 20: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 25: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 26: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 53: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 55: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 75: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 76: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 77: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 78: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10456, location 89: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 4: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10457, location 19: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 20: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 53: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 73: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 75: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 76: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 77: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 78: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10457, location 88: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 18: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 19: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 20: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 70: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 72: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 73: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10458, location 75: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10459, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10459, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10459, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10459, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10459, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10459, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10459, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10459, location 73: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10459, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10459, location 75: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10459, location 99: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10460, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10460, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10460, location 53: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10460, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10460, location 75: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10460, location 76: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10460, location 77: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10460, location 94: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10460, location 98: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10460, location 99: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10461, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10461, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10461, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10461, location 7: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10461, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10461, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10461, location 25: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10461, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10461, location 47: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 3: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 39: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10462, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 53: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 54: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 73: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 75: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 76: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 77: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 78: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10462, location 97: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10463, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10463, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10463, location 3: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10463, location 4: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 10463, location 12: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10463, location 13: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10463, location 14: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10463, location 15: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10463, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10463, location 53: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10463, location 54: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10463, location 55: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10463, location 99: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10464, location 9: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 10465, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10465, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10465, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10465, location 3: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10465, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10465, location 25: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10465, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10465, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10465, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10465, location 53: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10466, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10466, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10466, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10466, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10466, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10466, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10466, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10466, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10466, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10466, location 72: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10466, location 73: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10466, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 52: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 53: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 54: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 55: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 75: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 76: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 77: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 78: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 86: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 98: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10467, location 99: Small = 0.0, Medium = 0.0, Large = 1.0
# Expand facility in zip code 10468, facility 44: X = 1.0, Y = 0.0
# Expand facility in zip code 10468, facility 207: X = 1.0, Y = 0.0
# New facility in zip code 10468, location 18: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 10468, location 19: Small = 0.0, Medium = 0.0, Large = 1.0
# ...
# New facility in zip code 14127, location 32: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14127, location 40: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14131, location 99: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14132, location 52: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14136, location 84: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14138, location 0: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14141, location 99: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14145, location 1: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14150, location 42: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14171, location 0: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14172, location 1: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14174, location 40: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14201, location 25: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14201, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14202, location 0: Small = 1.0, Medium = 0.0, Large = 0.0
# Expand facility in zip code 14204, facility 1: X = 2.0, Y = 0.0
# New facility in zip code 14204, location 80: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14206, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14206, location 23: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14206, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14207, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14207, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14207, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14207, location 58: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14208, location 22: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14208, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14211, location 9: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14211, location 10: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14211, location 21: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14211, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14211, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14211, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14212, location 33: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14212, location 37: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14212, location 40: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14213, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14213, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14213, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14213, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14213, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14213, location 72: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14214, location 9: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14214, location 13: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14214, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14215, location 23: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14215, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14215, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14215, location 72: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14215, location 73: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14215, location 74: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14215, location 96: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14215, location 97: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14216, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14216, location 1: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14216, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14216, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14216, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14217, location 11: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14217, location 28: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14218, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14218, location 23: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14218, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14218, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14219, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# Expand facility in zip code 14220, facility 4: X = 9.012257985576296e-07, Y = 0.0
# New facility in zip code 14220, location 15: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14220, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14220, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14220, location 72: Small = 0.0, Medium = 0.0, Large = 0.9999997598034586
# New facility in zip code 14221, location 2: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14221, location 4: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14221, location 5: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14221, location 47: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14221, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14222, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14222, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14222, location 82: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14223, location 3: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14223, location 9: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14223, location 37: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14224, location 31: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14224, location 34: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14224, location 58: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14224, location 64: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14225, location 3: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14225, location 9: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14225, location 37: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14226, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14226, location 49: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14226, location 51: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14227, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14227, location 83: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14228, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14228, location 46: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14301, location 17: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14301, location 23: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14303, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14303, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14304, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14304, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14305, location 9: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14305, location 19: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14305, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14411, location 49: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14414, location 36: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14416, location 96: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14420, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14423, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14424, location 21: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14425, location 93: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14425, location 98: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14425, location 99: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14432, location 57: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14433, location 19: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14433, location 86: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14437, location 76: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14445, location 96: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14450, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14450, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14450, location 73: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14450, location 96: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14456, location 9: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14456, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14464, location 26: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14464, location 33: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14468, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14468, location 23: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14468, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14470, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14470, location 71: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14472, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14472, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14476, location 25: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14481, location 74: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14486, location 0: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14505, location 96: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14510, location 99: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14521, location 84: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14525, location 25: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14526, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14526, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14526, location 49: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14526, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14532, location 78: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14536, location 0: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14541, location 84: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14546, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14546, location 50: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14560, location 99: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14564, location 3: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14568, location 78: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14569, location 74: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14580, location 0: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14580, location 10: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14580, location 22: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14580, location 50: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14580, location 61: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14586, location 23: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14586, location 24: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14589, location 11: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14589, location 83: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14590, location 25: Small = 0.0, Medium = 1.0, Large = 0.0
# Expand facility in zip code 14608, facility 14: X = 4.0, Y = 0.0
# New facility in zip code 14609, location 15: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14609, location 40: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14609, location 41: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14609, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14612, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14612, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14612, location 57: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14612, location 72: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14612, location 95: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14617, location 9: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14617, location 48: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14621, location 1: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14621, location 14: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14621, location 15: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14621, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14621, location 46: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14621, location 55: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14622, location 24: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14622, location 80: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14625, location 96: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14717, location 37: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14727, location 49: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14731, location 76: Small = 1.0, Medium = 0.0, Large = 0.0
# New facility in zip code 14747, location 1: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14767, location 45: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14770, location 25: Small = 0.0, Medium = 1.0, Large = 0.0
# New facility in zip code 14772, location 45: Small = 0.0, Medium = 0.0, Large = 1.0
# New facility in zip code 14806, location 50: Small = 0.0, Medium = 1.0, Large = 0.0

# %%
if model_pt2.Status == grb.GRB.OPTIMAL:
    print(f"The minimal funding is {model_pt2.ObjVal:.2f}")
# Out:
# The minimal funding is 339088899.88

# %%
# Previous answer : The minimal funding is 320307702.23
# We now have : The minimal funding is 339088899.88

# %%
if model_pt2.Status == grb.GRB.OPTIMAL:
    print(f"The minimal funding is ${model_pt2.ObjVal:.2f}")
# Out:
# The minimal funding is $339088899.88

# %%
# Retrieving results of expansion
zip_code_cols = []
x_cols = []
y_cols = []

for z in zip_codes:
    for j in range(num_facilities[z]):
        zip_code_cols.append(z)
        x_cols.append(decision_varsX[z][j].x)
        y_cols.append(decision_varsY[z][j].x)

# %%
df_expand = pd.DataFrame({
    "zip_code": zip_code_cols,
    "expand_0-5": x_cols,
    "expand_5-12": y_cols
})

# %%
df_updated = df_current.drop("upper_bound", axis = 1)\
                       .merge(df_expand.drop("zip_code", axis = 1), left_index = True, right_index = True)

df_expand_grouped = df_updated.groupby("zip_code")[["expand_0-5", "expand_5-12"]].sum().reset_index()
df_expand_grouped
# Out:
#      zip_code  expand_0-5  expand_5-12
# 0     10001.0         0.0          0.0
# 1     10002.0         0.0          0.0
# 2     10003.0         0.0          0.0
# 3     10004.0         0.0          0.0
# 4     10005.0         0.0          0.0
# ..        ...         ...          ...
# 948   14227.0         0.0          0.0
# 949   14228.0         0.0          0.0
# 950   14301.0         0.0          0.0
# 951   14303.0         0.0          0.0
# 952   14304.0         0.0          0.0
#
# [953 rows x 3 columns]

# %%
df_updated
# Out:
#        zip_code  current_0-5  current_5-12  total_capacity   latitude  \
# 0       10001.0          0.0          84.0            84.0  40.748836
# 1       10001.0          5.0          11.0            16.0  40.748911
# 2       10001.0          0.0          17.0            17.0  40.752093
# 3       10001.0          2.0           6.0             8.0  40.748296
# 4       10001.0          0.0          79.0            79.0  40.749247
# ...         ...          ...           ...             ...        ...
# 14221   14303.0         10.0           0.0            10.0  43.086670
# 14223   14304.0          0.0         100.0           100.0  43.084443
# 14224   14304.0        185.0          17.0           202.0  43.091888
# 14225   14304.0         36.0          16.0            52.0  43.099935
# 14226   14304.0          2.0           6.0             8.0  43.066180
#
#        longitude  expand_0-5  expand_5-12
# 0     -73.999810         0.0          0.0
# 1     -74.001546         0.0          0.0
# 2     -74.002588         0.0          0.0
# 3     -74.001263         0.0          0.0
# 4     -74.001598         0.0          0.0
# ...          ...         ...          ...
# 14221 -79.020885         0.0          0.0
# 14223 -78.973353         0.0          0.0
# 14224 -78.907078         0.0          0.0
# 14225 -78.977003         0.0          0.0
# 14226 -78.922352         0.0          0.0
#
# [13734 rows x 8 columns]

# %%
(df_updated[["expand_0-5", "expand_5-12"]] != 0).sum()
# Out:
# expand_0-5     25
# expand_5-12     5
# dtype: int64

# %%
df_expand_grouped.sum()
# Out:
# zip_code       1.164176e+07
# expand_0-5     2.300001e+01
# expand_5-12    1.000000e+01
# dtype: float64

# %%
df_temp = pd.merge(
    left = df_main.reset_index().drop(["demand_policy", 
                                       "gap_policy", 
                                       "demand_not_desert", 
                                       "gap_not_desert",
                                       "population_5-12"
                                       ], axis = 1),
    right = df_expand_grouped,
    on = "zip_code",
    how = "left"
)

# %%
zip_code_cols = []
small_new = []
medium_new = []
large_new = []

for z in zip_codes:
    for k in range(100):
        zip_code_cols.append(z)
        small_new.append(decision_varsS[z][k].x)
        medium_new.append(decision_varsM[z][k].x)
        large_new.append(decision_varsL[z][k].x)

df_new_locs = pd.DataFrame({
    "zip_code": zip_code_cols,
    "small": small_new,
    "medium": medium_new,
    "large": large_new
})

df_new = df_new_locs.groupby("zip_code")[["small", "medium", "large"]].sum().reset_index()

# %%
data_temp = df_locations.merge(df_new_locs.drop("zip_code", axis = 1), left_index = True, right_index = True)
df_new_grouped = data_temp.groupby("zip_code").agg(
                                                    latitude = ("latitude", "mean"),
                                                    longitude = ("longitude", "mean"),
                                                    small = ("small", "sum"),
                                                    medium = ("medium", "sum"),
                                                    large = ("large", "sum")
                                                ).reset_index()

df_new_grouped["new_0-5"] = df_new_grouped["small"] * 50 + df_new_grouped["medium"] * 100 + df_new_grouped["large"] * 200
df_new_grouped["new_total"] = df_new_grouped["small"] * 100 + df_new_grouped["medium"] * 200 + df_new_grouped["large"] * 400
df_new_grouped
# Out:
#       zip_code   latitude  longitude  small  medium  large  new_0-5  new_total
# 0        10001  40.748323 -73.997539    0.0     1.0    2.0    500.0     1000.0
# 1        10002  40.715579 -73.987763    0.0     0.0    7.0   1400.0     2800.0
# 2        10003  40.730699 -73.988734    0.0     0.0    5.0   1000.0     2000.0
# 3        10004  40.715242 -74.005619    0.0     1.0    1.0    300.0      600.0
# 4        10005  40.705546 -74.007167    0.0     0.0    2.0    400.0      800.0
# ...        ...        ...        ...    ...     ...    ...      ...        ...
# 1002     14586  43.040930 -77.687060    0.0     1.0    0.0    100.0      200.0
# 1003     14589  43.242386 -77.169969    0.0     1.0    0.0    100.0      200.0
# 1004     14590  43.233995 -76.821190    0.0     1.0    0.0    100.0      200.0
# 1005     14608  43.151728 -77.626069    0.0     0.0    1.0    200.0      400.0
# 1006     14609  43.173349 -77.563389    0.0     1.0    0.0    100.0      200.0
#
# [1007 rows x 8 columns]

# %%
df_new_grouped.drop(["zip_code", "latitude", "longitude"], axis = 1).sum()
# Out:
# small        3.230000e+02
# medium       2.670000e+02
# large        2.541000e+03
# new_0-5      5.510500e+05
# new_total    1.102100e+06
# dtype: float64

# %%
df_temp
# Out:
#       zip_code  population_0-5  population_total  high demand  current_0-5  \
# 0        10001             744              2140            0            9
# 1        10002            2142              7267            0           93
# 2        10003            1440              2970            0            0
# 3        10004             433               672            0            0
# 4        10005             484               794            1            0
# ...        ...             ...               ...          ...          ...
# 1002     14747             156               362            0            4
# 1003     14767             101               422            0            5
# 1004     14770             137               482            0           15
# 1005     14772             256               635            0           37
# 1006     14806             127               339            0            5
#
#       current_5-12  expand_0-5  expand_5-12
# 0              600         0.0          0.0
# 1             4628         0.0          0.0
# 2             1995         0.0          0.0
# 3              263         0.0          0.0
# 4               39         0.0          0.0
# ...            ...         ...          ...
# 1002            11         NaN          NaN
# 1003            11         NaN          NaN
# 1004            55         NaN          NaN
# 1005            71         NaN          NaN
# 1006            11         NaN          NaN
#
# [1007 rows x 8 columns]

# %%
df_results = pd.merge(
    left = df_temp,
    right = df_new_grouped,
    on = "zip_code"
)

df_results["updated_0-5"] = df_results["current_0-5"] + df_results["expand_0-5"] + df_results["new_0-5"]
df_results["updated_total"] = df_results["current_0-5"] + df_results["current_5-12"] + df_results["expand_0-5"] + df_results["expand_5-12"] + df_results["new_total"]
df_results
# Out:
#      zip_code  population_0-5  population_total  high demand  current_0-5  \
# 0       10001             744              2140            0            9
# 1       10002            2142              7267            0           93
# 2       10003            1440              2970            0            0
# 3       10004             433               672            0            0
# 4       10005             484               794            1            0
# ..        ...             ...               ...          ...          ...
# 988     14586             386              1934            0           11
# 989     14589             562              1241            0           86
# 990     14590             112               657            0           46
# 991     14608             726              1951            0          480
# 992     14609            2529              6206            0          929
#
#      current_5-12  expand_0-5  expand_5-12   latitude  longitude  small  \
# 0             600         0.0          0.0  40.748323 -73.997539    0.0
# 1            4628         0.0          0.0  40.715579 -73.987763    0.0
# 2            1995         0.0          0.0  40.730699 -73.988734    0.0
# 3             263         0.0          0.0  40.715242 -74.005619    0.0
# 4              39         0.0          0.0  40.705546 -74.007167    0.0
# ..            ...         ...          ...        ...        ...    ...
# 988            29         NaN          NaN  43.040930 -77.687060    0.0
# 989            16         NaN          NaN  43.242386 -77.169969    0.0
# 990             0         NaN          NaN  43.233995 -76.821190    0.0
# 991           284         NaN          NaN  43.151728 -77.626069    0.0
# 992          1175         NaN          NaN  43.173349 -77.563389    0.0
#
#      medium  large  new_0-5  new_total  updated_0-5  updated_total
# 0       1.0    2.0    500.0     1000.0        509.0         1609.0
# 1       0.0    7.0   1400.0     2800.0       1493.0         7521.0
# 2       0.0    5.0   1000.0     2000.0       1000.0         3995.0
# 3       1.0    1.0    300.0      600.0        300.0          863.0
# 4       0.0    2.0    400.0      800.0        400.0          839.0
# ..      ...    ...      ...        ...          ...            ...
# 988     1.0    0.0    100.0      200.0          NaN            NaN
# 989     1.0    0.0    100.0      200.0          NaN            NaN
# 990     1.0    0.0    100.0      200.0          NaN            NaN
# 991     0.0    1.0    200.0      400.0          NaN            NaN
# 992     1.0    0.0    100.0      200.0          NaN            NaN
#
# [993 rows x 17 columns]

# %%
df_results["ratio_total"] = (df_results["current_0-5"] + df_results["current_5-12"]) / df_results["population_total"]
df_results["ratio_0-5"] = df_results["current_0-5"] / df_results["population_0-5"]

df_results["updated_ratio_total"] = df_results["updated_total"] / df_results["population_total"]
df_results["updated_ratio_0-5"] = df_results["updated_0-5"] / df_results["population_0-5"]
df_results
# Out:
#      zip_code  population_0-5  population_total  high demand  current_0-5  \
# 0       10001             744              2140            0            9
# 1       10002            2142              7267            0           93
# 2       10003            1440              2970            0            0
# 3       10004             433               672            0            0
# 4       10005             484               794            1            0
# ..        ...             ...               ...          ...          ...
# 988     14586             386              1934            0           11
# 989     14589             562              1241            0           86
# 990     14590             112               657            0           46
# 991     14608             726              1951            0          480
# 992     14609            2529              6206            0          929
#
#      current_5-12  expand_0-5  expand_5-12   latitude  longitude  ...  medium  \
# 0             600         0.0          0.0  40.748323 -73.997539  ...     1.0
# 1            4628         0.0          0.0  40.715579 -73.987763  ...     0.0
# 2            1995         0.0          0.0  40.730699 -73.988734  ...     0.0
# 3             263         0.0          0.0  40.715242 -74.005619  ...     1.0
# 4              39         0.0          0.0  40.705546 -74.007167  ...     0.0
# ..            ...         ...          ...        ...        ...  ...     ...
# 988            29         NaN          NaN  43.040930 -77.687060  ...     1.0
# 989            16         NaN          NaN  43.242386 -77.169969  ...     1.0
# 990             0         NaN          NaN  43.233995 -76.821190  ...     1.0
# 991           284         NaN          NaN  43.151728 -77.626069  ...     0.0
# 992          1175         NaN          NaN  43.173349 -77.563389  ...     1.0
#
#      large  new_0-5  new_total  updated_0-5  updated_total  ratio_total  \
# 0      2.0    500.0     1000.0        509.0         1609.0     0.284579
# 1      7.0   1400.0     2800.0       1493.0         7521.0     0.649649
# 2      5.0   1000.0     2000.0       1000.0         3995.0     0.671717
# 3      1.0    300.0      600.0        300.0          863.0     0.391369
# 4      2.0    400.0      800.0        400.0          839.0     0.049118
# ..     ...      ...        ...          ...            ...          ...
# 988    0.0    100.0      200.0          NaN            NaN     0.020683
# 989    0.0    100.0      200.0          NaN            NaN     0.082192
# 990    0.0    100.0      200.0          NaN            NaN     0.070015
# 991    1.0    200.0      400.0          NaN            NaN     0.391594
# 992    0.0    100.0      200.0          NaN            NaN     0.339027
#
#      ratio_0-5  updated_ratio_total  updated_ratio_0-5
# 0     0.012097             0.751869           0.684140
# 1     0.043417             1.034953           0.697012
# 2     0.000000             1.345118           0.694444
# 3     0.000000             1.284226           0.692841
# 4     0.000000             1.056675           0.826446
# ..         ...                  ...                ...
# 988   0.028497                  NaN                NaN
# 989   0.153025                  NaN                NaN
# 990   0.410714                  NaN                NaN
# 991   0.661157                  NaN                NaN
# 992   0.367339                  NaN                NaN
#
# [993 rows x 21 columns]

# %%
df_results.max()
# Out:
# zip_code               14609.00000
# population_0-5         12125.00000
# population_total       26962.00000
# high demand                1.00000
# current_0-5             1617.00000
# current_5-12            6244.00000
# expand_0-5                 4.00000
# expand_5-12                5.00000
# latitude                  44.98837
# longitude                -71.94420
# small                      1.00000
# medium                     1.00000
# large                     38.00000
# new_0-5                 7700.00000
# new_total              15400.00000
# updated_0-5             7915.00000
# updated_total          18487.00000
# ratio_total                    inf
# ratio_0-5                      inf
# updated_ratio_total            inf
# updated_ratio_0-5              inf
# dtype: float64

# %%
df_results.query("`new_0-5` == 0")
# Out:
#      zip_code  population_0-5  population_total  high demand  current_0-5  \
# 81      10504             521              1490            0          547
# 85      10510             375              1458            0          378
# 90      10520             618              1895            0          546
# 102     10543            1142              3629            0          430
# 115     10576              98               491            0            0
# 124     10594             359               937            0           10
# 129     10604             707              2375            0          441
# 136     10705            1959              6024            0          447
# 143     10803             656              2829            0          559
# 146     10901            1279              4145            0          334
# 151     10919              23               120            0            0
# 161     10940            3426              8995            0          872
# 171     10965             984              2834            0          396
# 183     10992             584              1693            0          232
# 196     11040            1947              5564            0          733
# 299     11545             372              1802            0          221
# 346     11724             241               604            0           77
# 376     11767             642              2119            0          130
# 413     11951            1224              3055            0          132
# 423     11978             101               461            0          175
# 450     12084             287               828            0            0
# 451     12085               0                19            0           54
# 463     12134             178               506            0            0
# 494     12204             830              1574            0            0
# 495     12205            1306              3721            0          544
# 498     12208             930              2046            0          558
# 503     12303            1262              4558            0          506
# 510     12401            2148              5424            0          571
# 516     12428             153               871            0           71
# 518     12434              85               177            0            2
# 524     12457              99               156            0            5
# 608     12832             255               862            0           11
# 633     12923              35                72            0            5
# 646     12958              42               265            0           10
# 649     12962             261               787            0           18
# 722     13206            1056              2586            0          107
# 729     13214             456              1331            0          225
# 731     13219             924              2314            0          182
# 753     13365             577              1685            0           66
# 755     13368              93               183            0           32
# 759     13408              96               286            0           66
# 769     13439             244               571            0           15
# 804     13642             605              1175            0           54
# 823     13732             386              1108            0           31
# 844     13803             376               975            0           38
# 882     14040             136               332            0           46
# 887     14051            1083              3046            0          216
# 912     14127            1666              4566            0          834
# 917     14141             397              1157            0          404
# 918     14145             106               142            1           10
# 978     14526            1296              3313            0          211
# 983     14560              62               262            0            5
#
#      current_5-12  expand_0-5  expand_5-12   latitude  longitude  ...  medium  \
# 81            159         0.0          0.0  41.136907 -73.699772  ...     0.0
# 85            326         0.0          0.0  41.144767 -73.834430  ...     0.0
# 90            241         0.0          0.0  41.217498 -73.891619  ...     0.0
# 102           437         0.0          0.0  40.952594 -73.734962  ...     0.0
# 115            40         0.0          0.0  41.205137 -73.573486  ...     0.0
# 124            22         0.0          0.0  41.119122 -73.773310  ...     0.0
# 129           286         0.0          0.0  41.060355 -73.739919  ...     0.0
# 136          1247         0.0          5.0  40.917682 -73.894579  ...     0.0
# 143           101         0.0          0.0  40.903877 -73.807995  ...     0.0
# 146           304         0.0          0.0  41.115965 -74.124589  ...     0.0
# 151           100         0.0          0.0  41.525323 -74.384751  ...     0.0
# 161           680         0.0          0.0  41.450992 -74.469799  ...     0.0
# 171           196         0.0          0.0  41.062948 -74.015601  ...     0.0
# 183           128         0.0          0.0  41.423769 -74.160084  ...     0.0
# 196           487         0.0          0.0  40.728947 -73.683612  ...     0.0
# 299           488         0.0          0.0  40.828555 -73.607091  ...     0.0
# 346            51         0.0          0.0  40.859954 -73.441376  ...     0.0
# 376            78         0.0          0.0  40.846764 -73.147829  ...     0.0
# 413            55         1.0          0.0  40.766201 -72.853865  ...     0.0
# 423            58         0.0          0.0  40.830400 -72.647406  ...     0.0
# 450           140         0.0          0.0  42.697575 -73.897641  ...     0.0
# 451            20         0.0          0.0  42.701634 -73.966491  ...     0.0
# 463            80         0.0          0.0  43.266494 -74.229381  ...     0.0
# 494            30         0.0          0.0  42.683880 -73.735765  ...     0.0
# 495           650         0.0          0.0  42.719749 -73.820578  ...     0.0
# 498           362         0.0          0.0  42.656784 -73.796899  ...     0.0
# 503           450         0.0          0.0  42.782941 -73.944200  ...     0.0
# 510           319         0.0          0.0  41.969117 -74.067079  ...     0.0
# 516            68         0.0          0.0  41.721912 -74.414949  ...     0.0
# 518             6         0.0          0.0  42.362659 -74.494045  ...     0.0
# 524            11         0.0          0.0  42.043272 -74.248790  ...     0.0
# 608            29         0.0          0.0  43.378125 -73.298318  ...     0.0
# 633            11         0.0          0.0  44.942943 -73.936520  ...     0.0
# 646            22         0.0          0.0  44.958814 -73.583832  ...     0.0
# 649            96         1.0          0.0  44.690397 -73.577258  ...     0.0
# 722           137         0.0          0.0  43.068376 -76.110631  ...     0.0
# 729           145         0.0          0.0  43.039681 -76.071887  ...     0.0
# 731            52         0.0          0.0  43.041641 -76.225768  ...     0.0
# 753           118         0.0          0.0  43.047032 -74.860585  ...     0.0
# 755             6         0.0          0.0  43.625013 -75.355711  ...     0.0
# 759            23         0.0          0.0  42.909321 -75.648316  ...     0.0
# 769             0         0.0          0.0  42.839600 -74.972148  ...     0.0
# 804            28         0.0          0.0  44.328322 -75.465132  ...     0.0
# 823            95         0.0          0.0  42.056119 -76.151597  ...     0.0
# 844            20         0.0          0.0  42.452683 -76.039486  ...     0.0
# 882             7         0.0          0.0  42.894634 -78.387415  ...     0.0
# 887           168         0.0          0.0  43.042186 -78.699054  ...     0.0
# 912           291         0.0          0.0  42.764406 -78.750492  ...     0.0
# 917            61         0.0          0.0  42.519634 -78.685053  ...     0.0
# 918            22         0.0          0.0  42.725724 -78.434818  ...     0.0
# 978           568         NaN          NaN  43.138972 -77.456383  ...     0.0
# 983            11         NaN          NaN  42.677899 -77.577390  ...     0.0
#
#      large  new_0-5  new_total  updated_0-5  updated_total  ratio_total  \
# 81     0.0      0.0        0.0        547.0          706.0     0.473826
# 85     0.0      0.0        0.0        378.0          704.0     0.482853
# 90     0.0      0.0        0.0        546.0          787.0     0.415303
# 102    0.0      0.0        0.0        430.0          867.0     0.238909
# 115    0.0      0.0        0.0          0.0           40.0     0.081466
# 124    0.0      0.0        0.0         10.0           32.0     0.034152
# 129    0.0      0.0        0.0        441.0          727.0     0.306105
# 136    0.0      0.0        0.0        447.0         1699.0     0.281208
# 143    0.0      0.0        0.0        559.0          660.0     0.233298
# 146    0.0      0.0        0.0        334.0          638.0     0.153920
# 151    0.0      0.0        0.0          0.0          100.0     0.833333
# 161    0.0      0.0        0.0        872.0         1552.0     0.172540
# 171    0.0      0.0        0.0        396.0          592.0     0.208892
# 183    0.0      0.0        0.0        232.0          360.0     0.212640
# 196    0.0      0.0        0.0        733.0         1220.0     0.219267
# 299    0.0      0.0        0.0        221.0          709.0     0.393452
# 346    0.0      0.0        0.0         77.0          128.0     0.211921
# 376    0.0      0.0        0.0        130.0          208.0     0.098160
# 413    0.0      0.0        0.0        133.0          188.0     0.061211
# 423    0.0      0.0        0.0        175.0          233.0     0.505423
# 450    0.0      0.0        0.0          0.0          140.0     0.169082
# 451    0.0      0.0        0.0         54.0           74.0     3.894737
# 463    0.0      0.0        0.0          0.0           80.0     0.158103
# 494    0.0      0.0        0.0          0.0           30.0     0.019060
# 495    0.0      0.0        0.0        544.0         1194.0     0.320881
# 498    0.0      0.0        0.0        558.0          920.0     0.449658
# 503    0.0      0.0        0.0        506.0          956.0     0.209741
# 510    0.0      0.0        0.0        571.0          890.0     0.164086
# 516    0.0      0.0        0.0         71.0          139.0     0.159587
# 518    0.0      0.0        0.0          2.0            8.0     0.045198
# 524    0.0      0.0        0.0          5.0           16.0     0.102564
# 608    0.0      0.0        0.0         11.0           40.0     0.046404
# 633    0.0      0.0        0.0          5.0           16.0     0.222222
# 646    0.0      0.0        0.0         10.0           32.0     0.120755
# 649    0.0      0.0        0.0         19.0          115.0     0.144854
# 722    0.0      0.0        0.0        107.0          244.0     0.094354
# 729    0.0      0.0        0.0        225.0          370.0     0.277986
# 731    0.0      0.0        0.0        182.0          234.0     0.101124
# 753    0.0      0.0        0.0         66.0          184.0     0.109199
# 755    0.0      0.0        0.0         32.0           38.0     0.207650
# 759    0.0      0.0        0.0         66.0           89.0     0.311189
# 769    0.0      0.0        0.0         15.0           15.0     0.026270
# 804    0.0      0.0        0.0         54.0           82.0     0.069787
# 823    0.0      0.0        0.0         31.0          126.0     0.113718
# 844    0.0      0.0        0.0         38.0           58.0     0.059487
# 882    0.0      0.0        0.0         46.0           53.0     0.159639
# 887    0.0      0.0        0.0        216.0          384.0     0.126067
# 912    0.0      0.0        0.0        834.0         1125.0     0.246386
# 917    0.0      0.0        0.0        404.0          465.0     0.401901
# 918    0.0      0.0        0.0         10.0           32.0     0.225352
# 978    0.0      0.0        0.0          NaN            NaN     0.235134
# 983    0.0      0.0        0.0          NaN            NaN     0.061069
#
#      ratio_0-5  updated_ratio_total  updated_ratio_0-5
# 81    1.049904             0.473826           1.049904
# 85    1.008000             0.482853           1.008000
# 90    0.883495             0.415303           0.883495
# 102   0.376532             0.238909           0.376532
# 115   0.000000             0.081466           0.000000
# 124   0.027855             0.034152           0.027855
# 129   0.623762             0.306105           0.623762
# 136   0.228178             0.282039           0.228178
# 143   0.852134             0.233298           0.852134
# 146   0.261142             0.153920           0.261142
# 151   0.000000             0.833333           0.000000
# 161   0.254524             0.172540           0.254524
# 171   0.402439             0.208892           0.402439
# 183   0.397260             0.212640           0.397260
# 196   0.376477             0.219267           0.376477
# 299   0.594086             0.393452           0.594086
# 346   0.319502             0.211921           0.319502
# 376   0.202492             0.098160           0.202492
# 413   0.107843             0.061538           0.108660
# 423   1.732673             0.505423           1.732673
# 450   0.000000             0.169082           0.000000
# 451        inf             3.894737                inf
# 463   0.000000             0.158103           0.000000
# 494   0.000000             0.019060           0.000000
# 495   0.416539             0.320881           0.416539
# 498   0.600000             0.449658           0.600000
# 503   0.400951             0.209741           0.400951
# 510   0.265829             0.164086           0.265829
# 516   0.464052             0.159587           0.464052
# 518   0.023529             0.045198           0.023529
# 524   0.050505             0.102564           0.050505
# 608   0.043137             0.046404           0.043137
# 633   0.142857             0.222222           0.142857
# 646   0.238095             0.120755           0.238095
# 649   0.068966             0.146125           0.072797
# 722   0.101326             0.094354           0.101326
# 729   0.493421             0.277986           0.493421
# 731   0.196970             0.101124           0.196970
# 753   0.114385             0.109199           0.114385
# 755   0.344086             0.207650           0.344086
# 759   0.687500             0.311189           0.687500
# 769   0.061475             0.026270           0.061475
# 804   0.089256             0.069787           0.089256
# 823   0.080311             0.113718           0.080311
# 844   0.101064             0.059487           0.101064
# 882   0.338235             0.159639           0.338235
# 887   0.199446             0.126067           0.199446
# 912   0.500600             0.246386           0.500600
# 917   1.017632             0.401901           1.017632
# 918   0.094340             0.225352           0.094340
# 978   0.162809                  NaN                NaN
# 983   0.080645                  NaN                NaN
#
# [52 rows x 21 columns]

# %%
zip_codes_nyc = df_care.query("city == 'New York'")['zip_code'].drop_duplicates().to_list()
