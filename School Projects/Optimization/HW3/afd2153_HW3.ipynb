# %% [markdown]
# # Assignment 3

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### (a) Definition of Parameters, Sets, Decision Variables, Constraints, and Objective
#
# ---
#
# **Sets:**
#
# - **Workers ($ W $)**: Set of workers
#   $$
#   W = [1, 2, 3, \dots, 100]
#   $$
#
# - **Departments ($ D $)**: List of departments
#   $$
#   D = [\text{Battery},\ \text{Body},\ \text{Assembly},\ \text{Paint},\ \text{Quality}]
#   $$
#
# - **Shifts ($ S $)**: List of shifts
#   $$
#   S = [\text{Morning},\ \text{Afternoon},\ \text{Night}]
#   $$
#
# - **Days ($ T $)**: List of days
#   $$
#   T = [\text{Mon},\ \text{Tue},\ \text{Wed},\ \text{Thur},\ \text{Fri},\ \text{Sat},\ \text{Sun}]
#   $$
#
# ---
#
# **Parameters:**
#
# - **Availability ($ A_{w,d,s,t} $)**: Binary parameter indicating whether worker $ w $ is available to work in department $ d $, shift $ s $, on day $ t $.
#
#   $$
#   A_{w,d,s,t} =
#   \begin{cases}
#   1 & \text{if worker } w \text{ is available} \\
#   0 & \text{otherwise}
#   \end{cases}
#   $$
#
# - **Preference Score ($ P_{w,d,s,t} $)**: Integer score from 1 to 10 indicating worker $ w $'s preference for working in department $ d $, shift $ s $, on day $ t $.
#
# - **Effectiveness Score ($ E_{w,d,s,t} $)**: Integer score from 1 to 10 indicating worker $ w $'s effectiveness in department $ d $, shift $ s $, on day $ t $.
#
# - **Minimum Workers Required ($ \text{MinWorkers}_{d,s,t} $)**: Minimum number of workers required in department $ d $, shift $ s $, on day $ t $.
#
# - **Maximum Workers Allowed ($ \text{MaxWorkers}_{d,s,t} $)**: Maximum number of workers allowed in department $ d $, shift $ s $, on day $ t $.
#
# ---
#
# **Decision Variables:**
#
# - **Assignment Variable ($ x_{w,d,s,t} $)**:
#
#   $$
#   x_{w,d,s,t} =
#   \begin{cases}
#   1 & \text{if worker } w \text{ is assigned to department } d, \text{ shift } s, \text{ on day } t \\
#   0 & \text{otherwise}
#   \end{cases}
#   $$
#
# ---
#
# **Objective Function:**
#
# Maximize the total preference-adjusted effectiveness:
#
# $$
# \max \quad Z = \sum_{w \in W} \sum_{d \in D} \sum_{s \in S} \sum_{t \in T} P_{w,d,s,t} \times E_{w,d,s,t} \times x_{w,d,s,t}
# $$
#
# ---
#
# **Constraints:**
#
# 1. **Availability Constraint**:
#
#    Workers can only be assigned to shifts they are available for.
#
#    $$
#    x_{w,d,s,t} \leq A_{w,d,s,t} \quad \forall\ w \in W,\ d \in D,\ s \in S,\ t \in T
#    $$
#
# 2. **One Shift per Day Constraint**:
#
#    Each worker can be assigned to at most one shift per day.
#
#    $$
#    \sum_{d \in D} \sum_{s \in S} x_{w,d,s,t} \leq 1 \quad \forall\ w \in W,\ t \in T
#    $$
#
# 3. **Maximum Working Days per Week Constraint**:
#
#    Each worker can work at most 5 days per week.
#
#    $$
#    \sum_{t \in T} \sum_{d \in D} \sum_{s \in S} x_{w,d,s,t} \leq 5 \quad \forall\ w \in W
#    $$
#
# 4. **Department Staffing Requirements**:
#
#    The number of workers assigned must meet the department's minimum and maximum staffing requirements.
#
#    $$
#    \text{MinWorkers}_{d,s,t} \leq \sum_{w \in W} x_{w,d,s,t} \leq \text{MaxWorkers}_{d,s,t} \quad \forall\ d \in D,\ s \in S,\ t \in T
#    $$
#
# 5. **Binary Decision Variables**:
#
#    $$
#    x_{w,d,s,t} \in \{0,1\} \quad \forall\ w \in W,\ d \in D,\ s \in S,\ t \in T
#    $$
#
# ---
#
# ### (b) Algebraic Formulation
#
# ---
#
# **Objective Function:**
#
# $$
# \max \quad Z = \sum_{w=1}^{100} \sum_{d \in D} \sum_{s \in S} \sum_{t \in T} P_{w,d,s,t} \cdot E_{w,d,s,t} \cdot x_{w,d,s,t}
# $$
#
# ---
#
# **Subject to:**
#
# 1. **Availability Constraints**:
#
#    $$
#    x_{w,d,s,t} \leq A_{w,d,s,t} \quad \forall\ w = 1, \dots, 100;\ d \in D;\ s \in S;\ t \in T
#    $$
#
# 2. **One Shift per Day Constraints**:
#
#    $$
#    \sum_{d \in D} \sum_{s \in S} x_{w,d,s,t} \leq 1 \quad \forall\ w = 1, \dots, 100;\ t \in T
#    $$
#
# 3. **Maximum Working Days per Week Constraints**:
#
#    $$
#    \sum_{t \in T} \sum_{d \in D} \sum_{s \in S} x_{w,d,s,t} \leq 5 \quad \forall\ w = 1, \dots, 100
#    $$
#
# 4. **Department Staffing Constraints**:
#
#    $$
#    \text{MinWorkers}_{d,s,t} \leq \sum_{w=1}^{100} x_{w,d,s,t} \leq \text{MaxWorkers}_{d,s,t} \quad \forall\ d \in D;\ s \in S;\ t \in T
#    $$
#
# 5. **Binary Variables**:
#
#    $$
#    x_{w,d,s,t} \in \{0,1\} \quad \forall\ w = 1, \dots, 100;\ d \in D;\ s \in S;\ t \in T
#    $$
#
# ---
#
# **Explanation:**
#
# - **Objective Function**: Maximizes the total sum of preference-adjusted effectiveness scores for all worker assignments.
#
# - **Constraints**:
#
#   1. **Availability**: Ensures workers are only assigned to shifts they are available for.
#
#   2. **One Shift per Day**: Prevents workers from being assigned to more than one shift in a single day.
#
#   3. **Maximum Working Days**: Limits each worker to a maximum of 5 working days per week.
#
#   4. **Staffing Requirements**: Ensures each department's shift meets its minimum and maximum staffing needs.
#
#   5. **Binary Variables**: Enforces that assignments are either made (1) or not made (0).

# %% [markdown]
# ### c)

# %%
import pandas as pd
import numpy as np

# Define Workers , Departments , Shifts , and Days
workers = [i for i in range(1, 101)]
departments = ['Battery', 'Body', 'Assembly', 'Paint', 'Quality']
shifts = ['Morning', 'Afternoon', 'Night']
days = ['Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sat', 'Sun']

# Create Workers DataFrame
workers_df = pd.DataFrame({
    'Worker_ID': np.repeat(workers , len(departments)*len(shifts)*len(days))
    ,
    'Department': np.tile(np.repeat(departments , len(shifts)*len(days)),len(workers)),
    'Shift': np.tile(np.repeat(shifts , len(days)), len(workers)*len(departments)),
    'Day': np.tile(days, len(workers)*len(departments)*len(shifts)),
    'Availability': np.random.choice([0, 1], len(workers)*len(departments)*len(shifts)*len(days)),
    'Preference_Score': np.random.randint(1, 10, len(workers)*len(departments)*len(shifts)*len(days)),
    'Effectiveness_Score': np.random.randint(1, 10, len(workers)*len(departments)*len(shifts)*len(days))
})

# Create Department DataFrame
dept_df = pd.DataFrame({
    'Department': np.repeat(departments , len(shifts)*len(days)),
    'Shift': np.tile(np.repeat(shifts , len(days)), len(departments)),
    'Day': np.tile(days, len(departments)*len(shifts)),
    'Min_Workers': np.random.randint(1, 5, len(departments)*len(shifts)*len(days)),
    'Max_Workers': np.random.randint(5, 10, len(departments)*len(shifts)*len(days))
})

# %%
# Initialize the model
m = Model("Workforce_Scheduling")

# Decision variables
x = {}
for w in workers:
    for d in departments:
        for s in shifts:
            for t in days:
                # Filter the workers_df to check availability
                available = workers_df[
                    (workers_df['Worker_ID'] == w) &
                    (workers_df['Department'] == d) &
                    (workers_df['Shift'] == s) &
                    (workers_df['Day'] == t)
                ]['Availability'].values
                if len(available) > 0:
                    x[w, d, s, t] = m.addVar(vtype=GRB.BINARY, name=f"x_{w}_{d}_{s}_{t}")

# Objective function
m.setObjective(
    quicksum(
        workers_df[
            (workers_df['Worker_ID'] == w) &
            (workers_df['Department'] == d) &
            (workers_df['Shift'] == s) &
            (workers_df['Day'] == t)
        ]['Preference_Score'].values[0] *
        workers_df[
            (workers_df['Worker_ID'] == w) &
            (workers_df['Department'] == d) &
            (workers_df['Shift'] == s) &
            (workers_df['Day'] == t)
        ]['Effectiveness_Score'].values[0] *
        x[w, d, s, t]
        for (w, d, s, t) in x
    ),
    GRB.MAXIMIZE
)

# Constraints

# 1. Availability constraint
for (w, d, s, t) in x:
    availability_value = workers_df[
        (workers_df['Worker_ID'] == w) &
        (workers_df['Department'] == d) &
        (workers_df['Shift'] == s) &
        (workers_df['Day'] == t)
    ]['Availability'].values[0]
    m.addConstr(x[w, d, s, t] <= availability_value, name=f"Avail_{w}_{d}_{s}_{t}")

# 2. Each worker can be assigned to at most one shift per day
for w in workers:
    for t in days:
        m.addConstr(
            quicksum(
                x[w, d, s, t] for d in departments for s in shifts if (w, d, s, t) in x
            ) <= 1,
            name=f"OneShiftPerDay_{w}_{t}"
        )

# 3. Each worker can work at most 5 days per week
for w in workers:
    m.addConstr(
        quicksum(
            x[w, d, s, t] for d in departments for s in shifts for t in days if (w, d, s, t) in x
        ) <= 5,
        name=f"MaxDays_{w}"
    )

# 4. Department staffing needs
for d in departments:
    for s in shifts:
        for t in days:
            min_workers = dept_df[
                (dept_df['Department'] == d) &
                (dept_df['Shift'] == s) &
                (dept_df['Day'] == t)
            ]['Min_Workers'].values[0]
            max_workers = dept_df[
                (dept_df['Department'] == d) &
                (dept_df['Shift'] == s) &
                (dept_df['Day'] == t)
            ]['Max_Workers'].values[0]
            m.addConstr(
                quicksum(
                    x[w, d, s, t] for w in workers if (w, d, s, t) in x
                ) >= min_workers,
                name=f"MinStaff_{d}_{s}_{t}"
            )
            m.addConstr(
                quicksum(
                    x[w, d, s, t] for w in workers if (w, d, s, t) in x
                ) <= max_workers,
                name=f"MaxStaff_{d}_{s}_{t}"
            )

# Optimize the model
m.setParam('OutputFlag', 0)  # cleaner output
m.optimize()

# Output results
if m.status == GRB.OPTIMAL:
    print("\nOptimal solution found:\n")
    for (w, d, s, t) in x:
        if x[w, d, s, t].X > 0.5:
            print(f"Worker {w} assigned to department {d}, shift {s}, on {t}")
else:
    print("\nNo optimal solution found.")
# Out:
# Optimal solution found:
#
# Worker 1 assigned to department Body, shift Morning, on Wed
# Worker 1 assigned to department Body, shift Night, on Mon
# Worker 1 assigned to department Paint, shift Morning, on Sun
# Worker 1 assigned to department Quality, shift Night, on Tue
# Worker 1 assigned to department Quality, shift Night, on Thur
# Worker 2 assigned to department Battery, shift Morning, on Tue
# Worker 2 assigned to department Battery, shift Morning, on Thur
# Worker 2 assigned to department Body, shift Night, on Sat
# Worker 2 assigned to department Paint, shift Morning, on Wed
# Worker 2 assigned to department Paint, shift Afternoon, on Sun
# Worker 3 assigned to department Body, shift Morning, on Wed
# Worker 3 assigned to department Body, shift Afternoon, on Fri
# Worker 3 assigned to department Assembly, shift Morning, on Sun
# Worker 3 assigned to department Paint, shift Morning, on Thur
# Worker 3 assigned to department Quality, shift Afternoon, on Mon
# Worker 4 assigned to department Body, shift Afternoon, on Wed
# Worker 4 assigned to department Paint, shift Night, on Thur
# Worker 4 assigned to department Paint, shift Night, on Fri
# Worker 4 assigned to department Quality, shift Afternoon, on Tue
# Worker 4 assigned to department Quality, shift Afternoon, on Sat
# Worker 5 assigned to department Battery, shift Morning, on Wed
# Worker 5 assigned to department Battery, shift Morning, on Sun
# Worker 5 assigned to department Body, shift Night, on Thur
# Worker 5 assigned to department Assembly, shift Afternoon, on Sat
# Worker 5 assigned to department Paint, shift Morning, on Fri
# Worker 6 assigned to department Battery, shift Morning, on Wed
# Worker 6 assigned to department Assembly, shift Morning, on Mon
# Worker 6 assigned to department Assembly, shift Morning, on Sat
# Worker 6 assigned to department Assembly, shift Afternoon, on Fri
# Worker 6 assigned to department Paint, shift Night, on Sun
# Worker 7 assigned to department Battery, shift Afternoon, on Fri
# Worker 7 assigned to department Body, shift Night, on Thur
# Worker 7 assigned to department Paint, shift Morning, on Mon
# Worker 7 assigned to department Quality, shift Morning, on Sat
# Worker 7 assigned to department Quality, shift Night, on Sun
# Worker 8 assigned to department Battery, shift Morning, on Mon
# Worker 8 assigned to department Assembly, shift Morning, on Sun
# Worker 8 assigned to department Assembly, shift Afternoon, on Thur
# Worker 8 assigned to department Assembly, shift Night, on Sat
# Worker 8 assigned to department Quality, shift Morning, on Fri
# Worker 9 assigned to department Battery, shift Afternoon, on Mon
# Worker 9 assigned to department Battery, shift Afternoon, on Fri
# Worker 9 assigned to department Assembly, shift Morning, on Thur
# Worker 9 assigned to department Paint, shift Night, on Wed
# Worker 9 assigned to department Quality, shift Morning, on Sun
# Worker 10 assigned to department Battery, shift Afternoon, on Thur
# Worker 10 assigned to department Body, shift Morning, on Fri
# Worker 10 assigned to department Assembly, shift Morning, on Sun
# Worker 10 assigned to department Quality, shift Afternoon, on Sat
# Worker 10 assigned to department Quality, shift Night, on Tue
# Worker 11 assigned to department Battery, shift Night, on Mon
# Worker 11 assigned to department Body, shift Afternoon, on Tue
# Worker 11 assigned to department Assembly, shift Night, on Sat
# Worker 11 assigned to department Paint, shift Afternoon, on Wed
# Worker 11 assigned to department Quality, shift Morning, on Fri
# Worker 12 assigned to department Body, shift Afternoon, on Wed
# Worker 12 assigned to department Assembly, shift Morning, on Sun
# Worker 12 assigned to department Paint, shift Afternoon, on Mon
# Worker 12 assigned to department Paint, shift Night, on Sat
# Worker 12 assigned to department Quality, shift Morning, on Thur
# Worker 13 assigned to department Body, shift Night, on Sun
# Worker 13 assigned to department Assembly, shift Night, on Wed
# Worker 13 assigned to department Paint, shift Afternoon, on Tue
# Worker 13 assigned to department Paint, shift Night, on Fri
# Worker 13 assigned to department Quality, shift Night, on Mon
# Worker 14 assigned to department Battery, shift Morning, on Sat
# Worker 14 assigned to department Battery, shift Afternoon, on Mon
# Worker 14 assigned to department Body, shift Morning, on Sun
# Worker 14 assigned to department Paint, shift Morning, on Fri
# Worker 14 assigned to department Quality, shift Morning, on Thur
# Worker 15 assigned to department Battery, shift Afternoon, on Sun
# Worker 15 assigned to department Assembly, shift Morning, on Sat
# Worker 15 assigned to department Assembly, shift Afternoon, on Fri
# Worker 15 assigned to department Paint, shift Night, on Tue
# Worker 15 assigned to department Quality, shift Morning, on Thur
# Worker 16 assigned to department Body, shift Morning, on Wed
# Worker 16 assigned to department Body, shift Morning, on Sun
# Worker 16 assigned to department Body, shift Afternoon, on Sat
# Worker 16 assigned to department Body, shift Night, on Fri
# Worker 16 assigned to department Paint, shift Night, on Tue
# Worker 17 assigned to department Battery, shift Morning, on Mon
# Worker 17 assigned to department Battery, shift Afternoon, on Fri
# Worker 17 assigned to department Assembly, shift Afternoon, on Sat
# Worker 17 assigned to department Assembly, shift Night, on Thur
# Worker 17 assigned to department Paint, shift Morning, on Sun
# Worker 18 assigned to department Battery, shift Afternoon, on Sun
# Worker 18 assigned to department Assembly, shift Morning, on Wed
# Worker 18 assigned to department Quality, shift Afternoon, on Thur
# Worker 18 assigned to department Quality, shift Night, on Mon
# Worker 18 assigned to department Quality, shift Night, on Tue
# Worker 19 assigned to department Body, shift Afternoon, on Sat
# Worker 19 assigned to department Body, shift Night, on Wed
# Worker 19 assigned to department Assembly, shift Afternoon, on Fri
# Worker 19 assigned to department Paint, shift Morning, on Tue
# Worker 19 assigned to department Paint, shift Night, on Thur
# Worker 20 assigned to department Body, shift Night, on Tue
# Worker 20 assigned to department Assembly, shift Afternoon, on Mon
# Worker 20 assigned to department Quality, shift Afternoon, on Wed
# Worker 20 assigned to department Quality, shift Afternoon, on Thur
# Worker 20 assigned to department Quality, shift Night, on Sun
# Worker 21 assigned to department Body, shift Afternoon, on Thur
# Worker 21 assigned to department Assembly, shift Morning, on Fri
# Worker 21 assigned to department Assembly, shift Morning, on Sat
# Worker 21 assigned to department Assembly, shift Afternoon, on Mon
# Worker 21 assigned to department Quality, shift Afternoon, on Wed
# Worker 22 assigned to department Battery, shift Night, on Fri
# Worker 22 assigned to department Body, shift Afternoon, on Sat
# Worker 22 assigned to department Assembly, shift Morning, on Thur
# Worker 22 assigned to department Paint, shift Afternoon, on Mon
# Worker 22 assigned to department Quality, shift Night, on Wed
# Worker 23 assigned to department Battery, shift Morning, on Fri
# Worker 23 assigned to department Battery, shift Night, on Mon
# Worker 23 assigned to department Battery, shift Night, on Thur
# Worker 23 assigned to department Assembly, shift Afternoon, on Sun
# Worker 23 assigned to department Paint, shift Afternoon, on Tue
# Worker 24 assigned to department Battery, shift Night, on Mon
# Worker 24 assigned to department Body, shift Morning, on Thur
# Worker 24 assigned to department Quality, shift Morning, on Wed
# Worker 24 assigned to department Quality, shift Morning, on Sun
# Worker 24 assigned to department Quality, shift Afternoon, on Fri
# Worker 25 assigned to department Battery, shift Night, on Wed
# Worker 25 assigned to department Body, shift Afternoon, on Sun
# Worker 25 assigned to department Body, shift Night, on Tue
# Worker 25 assigned to department Paint, shift Night, on Sat
# Worker 25 assigned to department Quality, shift Night, on Thur
# Worker 26 assigned to department Battery, shift Night, on Tue
# Worker 26 assigned to department Body, shift Morning, on Thur
# Worker 26 assigned to department Body, shift Morning, on Sun
# Worker 26 assigned to department Body, shift Afternoon, on Fri
# Worker 26 assigned to department Quality, shift Morning, on Sat
# Worker 27 assigned to department Body, shift Morning, on Thur
# Worker 27 assigned to department Body, shift Afternoon, on Mon
# Worker 27 assigned to department Assembly, shift Night, on Fri
# Worker 27 assigned to department Paint, shift Morning, on Tue
# Worker 27 assigned to department Quality, shift Afternoon, on Wed
# Worker 28 assigned to department Battery, shift Morning, on Mon
# Worker 28 assigned to department Assembly, shift Afternoon, on Wed
# Worker 28 assigned to department Assembly, shift Night, on Thur
# Worker 28 assigned to department Assembly, shift Night, on Sat
# Worker 28 assigned to department Quality, shift Night, on Sun
# Worker 29 assigned to department Battery, shift Morning, on Thur
# Worker 29 assigned to department Body, shift Morning, on Sun
# Worker 29 assigned to department Paint, shift Afternoon, on Tue
# Worker 29 assigned to department Quality, shift Morning, on Fri
# Worker 29 assigned to department Quality, shift Night, on Sat
# Worker 30 assigned to department Body, shift Afternoon, on Wed
# Worker 30 assigned to department Body, shift Night, on Sun
# Worker 30 assigned to department Assembly, shift Morning, on Tue
# Worker 30 assigned to department Paint, shift Night, on Fri
# Worker 30 assigned to department Quality, shift Afternoon, on Mon
# Worker 31 assigned to department Battery, shift Afternoon, on Wed
# Worker 31 assigned to department Body, shift Afternoon, on Sun
# Worker 31 assigned to department Assembly, shift Morning, on Fri
# Worker 31 assigned to department Paint, shift Night, on Mon
# Worker 31 assigned to department Paint, shift Night, on Thur
# Worker 32 assigned to department Battery, shift Morning, on Fri
# Worker 32 assigned to department Battery, shift Night, on Tue
# Worker 32 assigned to department Body, shift Afternoon, on Sat
# Worker 32 assigned to department Body, shift Night, on Sun
# Worker 32 assigned to department Paint, shift Afternoon, on Wed
# Worker 33 assigned to department Battery, shift Afternoon, on Sat
# Worker 33 assigned to department Battery, shift Night, on Sun
# Worker 33 assigned to department Body, shift Morning, on Fri
# Worker 33 assigned to department Assembly, shift Afternoon, on Tue
# Worker 33 assigned to department Quality, shift Morning, on Mon
# Worker 34 assigned to department Assembly, shift Afternoon, on Fri
# Worker 34 assigned to department Assembly, shift Afternoon, on Sat
# Worker 34 assigned to department Paint, shift Morning, on Thur
# Worker 34 assigned to department Quality, shift Morning, on Wed
# Worker 34 assigned to department Quality, shift Afternoon, on Sun
# Worker 35 assigned to department Battery, shift Morning, on Thur
# Worker 35 assigned to department Battery, shift Morning, on Sun
# Worker 35 assigned to department Body, shift Afternoon, on Fri
# Worker 35 assigned to department Body, shift Night, on Mon
# Worker 35 assigned to department Paint, shift Afternoon, on Sat
# Worker 36 assigned to department Battery, shift Morning, on Tue
# Worker 36 assigned to department Battery, shift Morning, on Fri
# Worker 36 assigned to department Battery, shift Afternoon, on Sat
# Worker 36 assigned to department Body, shift Night, on Wed
# Worker 36 assigned to department Quality, shift Morning, on Sun
# Worker 37 assigned to department Assembly, shift Afternoon, on Mon
# Worker 37 assigned to department Paint, shift Morning, on Thur
# Worker 37 assigned to department Paint, shift Night, on Wed
# Worker 37 assigned to department Quality, shift Morning, on Sun
# Worker 37 assigned to department Quality, shift Afternoon, on Fri
# Worker 38 assigned to department Paint, shift Afternoon, on Mon
# Worker 38 assigned to department Paint, shift Afternoon, on Sat
# Worker 38 assigned to department Quality, shift Afternoon, on Wed
# Worker 38 assigned to department Quality, shift Night, on Thur
# Worker 38 assigned to department Quality, shift Night, on Fri
# Worker 39 assigned to department Battery, shift Morning, on Sun
# Worker 39 assigned to department Assembly, shift Afternoon, on Tue
# Worker 39 assigned to department Assembly, shift Afternoon, on Fri
# Worker 39 assigned to department Assembly, shift Night, on Wed
# Worker 39 assigned to department Quality, shift Afternoon, on Mon
# Worker 40 assigned to department Battery, shift Night, on Fri
# Worker 40 assigned to department Body, shift Afternoon, on Sun
# Worker 40 assigned to department Assembly, shift Afternoon, on Mon
# Worker 40 assigned to department Assembly, shift Afternoon, on Tue
# Worker 40 assigned to department Paint, shift Morning, on Thur
# Worker 41 assigned to department Battery, shift Afternoon, on Tue
# Worker 41 assigned to department Battery, shift Afternoon, on Thur
# Worker 41 assigned to department Body, shift Morning, on Wed
# Worker 41 assigned to department Paint, shift Morning, on Sun
# Worker 41 assigned to department Quality, shift Afternoon, on Mon
# Worker 42 assigned to department Battery, shift Afternoon, on Sat
# Worker 42 assigned to department Battery, shift Night, on Wed
# Worker 42 assigned to department Battery, shift Night, on Thur
# Worker 42 assigned to department Paint, shift Morning, on Mon
# Worker 42 assigned to department Paint, shift Night, on Sun
# Worker 43 assigned to department Body, shift Afternoon, on Fri
# Worker 43 assigned to department Body, shift Night, on Thur
# Worker 43 assigned to department Body, shift Night, on Sat
# Worker 43 assigned to department Assembly, shift Morning, on Wed
# Worker 43 assigned to department Assembly, shift Night, on Tue
# Worker 44 assigned to department Battery, shift Afternoon, on Sat
# Worker 44 assigned to department Battery, shift Night, on Thur
# Worker 44 assigned to department Body, shift Morning, on Wed
# Worker 44 assigned to department Assembly, shift Morning, on Tue
# Worker 44 assigned to department Assembly, shift Afternoon, on Fri
# Worker 45 assigned to department Battery, shift Morning, on Tue
# Worker 45 assigned to department Battery, shift Night, on Thur
# Worker 45 assigned to department Assembly, shift Morning, on Fri
# Worker 45 assigned to department Paint, shift Morning, on Mon
# Worker 45 assigned to department Paint, shift Morning, on Sat
# Worker 46 assigned to department Body, shift Afternoon, on Fri
# Worker 46 assigned to department Body, shift Night, on Sat
# Worker 46 assigned to department Paint, shift Afternoon, on Sun
# Worker 46 assigned to department Paint, shift Night, on Mon
# Worker 46 assigned to department Quality, shift Afternoon, on Thur
# Worker 47 assigned to department Body, shift Morning, on Tue
# Worker 47 assigned to department Body, shift Night, on Thur
# Worker 47 assigned to department Assembly, shift Morning, on Mon
# Worker 47 assigned to department Assembly, shift Morning, on Fri
# Worker 47 assigned to department Quality, shift Afternoon, on Sat
# Worker 48 assigned to department Battery, shift Morning, on Mon
# Worker 48 assigned to department Assembly, shift Afternoon, on Sun
# Worker 48 assigned to department Assembly, shift Night, on Tue
# Worker 48 assigned to department Assembly, shift Night, on Fri
# Worker 48 assigned to department Paint, shift Afternoon, on Sat
# Worker 49 assigned to department Battery, shift Afternoon, on Tue
# Worker 49 assigned to department Body, shift Night, on Wed
# Worker 49 assigned to department Assembly, shift Night, on Thur
# Worker 49 assigned to department Paint, shift Night, on Mon
# Worker 49 assigned to department Quality, shift Morning, on Sat
# Worker 50 assigned to department Battery, shift Night, on Thur
# Worker 50 assigned to department Body, shift Afternoon, on Tue
# Worker 50 assigned to department Body, shift Night, on Mon
# Worker 50 assigned to department Body, shift Night, on Fri
# Worker 50 assigned to department Paint, shift Afternoon, on Wed
# Worker 51 assigned to department Battery, shift Morning, on Sat
# Worker 51 assigned to department Battery, shift Afternoon, on Mon
# Worker 51 assigned to department Battery, shift Afternoon, on Sun
# Worker 51 assigned to department Assembly, shift Afternoon, on Tue
# Worker 51 assigned to department Quality, shift Afternoon, on Fri
# Worker 52 assigned to department Battery, shift Night, on Sun
# Worker 52 assigned to department Assembly, shift Afternoon, on Fri
# Worker 52 assigned to department Assembly, shift Night, on Sat
# Worker 52 assigned to department Paint, shift Night, on Wed
# Worker 52 assigned to department Quality, shift Afternoon, on Tue
# Worker 53 assigned to department Battery, shift Morning, on Sat
# Worker 53 assigned to department Body, shift Morning, on Wed
# Worker 53 assigned to department Body, shift Morning, on Sun
# Worker 53 assigned to department Assembly, shift Morning, on Mon
# Worker 53 assigned to department Assembly, shift Afternoon, on Thur
# Worker 54 assigned to department Battery, shift Morning, on Fri
# Worker 54 assigned to department Battery, shift Afternoon, on Sun
# Worker 54 assigned to department Body, shift Night, on Tue
# Worker 54 assigned to department Assembly, shift Night, on Sat
# Worker 54 assigned to department Paint, shift Night, on Thur
# Worker 55 assigned to department Battery, shift Morning, on Mon
# Worker 55 assigned to department Battery, shift Afternoon, on Sat
# Worker 55 assigned to department Body, shift Morning, on Wed
# Worker 55 assigned to department Paint, shift Afternoon, on Thur
# Worker 55 assigned to department Quality, shift Morning, on Fri
# Worker 56 assigned to department Battery, shift Night, on Tue
# Worker 56 assigned to department Battery, shift Night, on Sun
# Worker 56 assigned to department Assembly, shift Night, on Wed
# Worker 56 assigned to department Quality, shift Afternoon, on Thur
# Worker 56 assigned to department Quality, shift Night, on Mon
# Worker 57 assigned to department Body, shift Morning, on Sun
# Worker 57 assigned to department Body, shift Afternoon, on Thur
# Worker 57 assigned to department Paint, shift Afternoon, on Mon
# Worker 57 assigned to department Paint, shift Night, on Sat
# Worker 57 assigned to department Quality, shift Night, on Fri
# Worker 58 assigned to department Battery, shift Night, on Wed
# Worker 58 assigned to department Paint, shift Morning, on Thur
# Worker 58 assigned to department Quality, shift Morning, on Tue
# Worker 58 assigned to department Quality, shift Morning, on Fri
# Worker 58 assigned to department Quality, shift Night, on Sun
# Worker 59 assigned to department Battery, shift Night, on Sat
# Worker 59 assigned to department Body, shift Afternoon, on Thur
# Worker 59 assigned to department Assembly, shift Afternoon, on Sun
# Worker 59 assigned to department Assembly, shift Night, on Mon
# Worker 59 assigned to department Paint, shift Afternoon, on Tue
# Worker 60 assigned to department Body, shift Morning, on Sun
# Worker 60 assigned to department Assembly, shift Morning, on Mon
# Worker 60 assigned to department Assembly, shift Night, on Tue
# Worker 60 assigned to department Paint, shift Afternoon, on Thur
# Worker 60 assigned to department Paint, shift Afternoon, on Sat
# Worker 61 assigned to department Battery, shift Afternoon, on Mon
# Worker 61 assigned to department Battery, shift Night, on Sat
# Worker 61 assigned to department Paint, shift Morning, on Wed
# Worker 61 assigned to department Paint, shift Afternoon, on Fri
# Worker 61 assigned to department Quality, shift Night, on Sun
# Worker 62 assigned to department Battery, shift Afternoon, on Tue
# Worker 62 assigned to department Battery, shift Afternoon, on Thur
# Worker 62 assigned to department Battery, shift Afternoon, on Sun
# Worker 62 assigned to department Quality, shift Afternoon, on Fri
# Worker 62 assigned to department Quality, shift Night, on Sat
# Worker 63 assigned to department Body, shift Morning, on Sat
# Worker 63 assigned to department Body, shift Afternoon, on Wed
# Worker 63 assigned to department Body, shift Night, on Mon
# Worker 63 assigned to department Paint, shift Afternoon, on Fri
# Worker 63 assigned to department Paint, shift Night, on Thur
# Worker 64 assigned to department Assembly, shift Morning, on Tue
# Worker 64 assigned to department Paint, shift Night, on Sun
# Worker 64 assigned to department Quality, shift Morning, on Mon
# Worker 64 assigned to department Quality, shift Morning, on Thur
# Worker 64 assigned to department Quality, shift Afternoon, on Wed
# Worker 65 assigned to department Battery, shift Morning, on Mon
# Worker 65 assigned to department Battery, shift Night, on Tue
# Worker 65 assigned to department Battery, shift Night, on Thur
# Worker 65 assigned to department Body, shift Night, on Wed
# Worker 65 assigned to department Body, shift Night, on Fri
# Worker 66 assigned to department Battery, shift Afternoon, on Thur
# Worker 66 assigned to department Battery, shift Night, on Sun
# Worker 66 assigned to department Body, shift Night, on Wed
# Worker 66 assigned to department Paint, shift Night, on Fri
# Worker 66 assigned to department Quality, shift Night, on Mon
# Worker 67 assigned to department Battery, shift Morning, on Mon
# Worker 67 assigned to department Body, shift Morning, on Fri
# Worker 67 assigned to department Body, shift Night, on Wed
# Worker 67 assigned to department Paint, shift Night, on Sat
# Worker 67 assigned to department Quality, shift Morning, on Tue
# Worker 68 assigned to department Battery, shift Morning, on Tue
# Worker 68 assigned to department Battery, shift Night, on Mon
# Worker 68 assigned to department Body, shift Night, on Wed
# Worker 68 assigned to department Assembly, shift Morning, on Fri
# Worker 68 assigned to department Assembly, shift Afternoon, on Thur
# Worker 69 assigned to department Body, shift Afternoon, on Sun
# Worker 69 assigned to department Body, shift Night, on Fri
# Worker 69 assigned to department Assembly, shift Afternoon, on Tue
# Worker 69 assigned to department Assembly, shift Night, on Mon
# Worker 69 assigned to department Quality, shift Night, on Wed
# Worker 70 assigned to department Body, shift Morning, on Wed
# Worker 70 assigned to department Body, shift Morning, on Sat
# Worker 70 assigned to department Body, shift Afternoon, on Tue
# Worker 70 assigned to department Paint, shift Afternoon, on Fri
# Worker 70 assigned to department Paint, shift Afternoon, on Sun
# Worker 71 assigned to department Battery, shift Night, on Sat
# Worker 71 assigned to department Assembly, shift Night, on Mon
# Worker 71 assigned to department Paint, shift Morning, on Tue
# Worker 71 assigned to department Paint, shift Morning, on Fri
# Worker 71 assigned to department Quality, shift Afternoon, on Sun
# Worker 72 assigned to department Battery, shift Morning, on Wed
# Worker 72 assigned to department Assembly, shift Night, on Fri
# Worker 72 assigned to department Paint, shift Morning, on Sun
# Worker 72 assigned to department Quality, shift Morning, on Mon
# Worker 72 assigned to department Quality, shift Night, on Thur
# Worker 73 assigned to department Battery, shift Afternoon, on Sat
# Worker 73 assigned to department Body, shift Afternoon, on Mon
# Worker 73 assigned to department Body, shift Night, on Fri
# Worker 73 assigned to department Assembly, shift Morning, on Thur
# Worker 73 assigned to department Quality, shift Morning, on Wed
# Worker 74 assigned to department Battery, shift Night, on Mon
# Worker 74 assigned to department Battery, shift Night, on Sun
# Worker 74 assigned to department Paint, shift Morning, on Sat
# Worker 74 assigned to department Quality, shift Afternoon, on Thur
# Worker 74 assigned to department Quality, shift Night, on Fri
# Worker 75 assigned to department Battery, shift Night, on Sun
# Worker 75 assigned to department Body, shift Morning, on Tue
# Worker 75 assigned to department Assembly, shift Morning, on Wed
# Worker 75 assigned to department Assembly, shift Morning, on Thur
# Worker 75 assigned to department Paint, shift Night, on Sat
# Worker 76 assigned to department Battery, shift Morning, on Tue
# Worker 76 assigned to department Body, shift Afternoon, on Sun
# Worker 76 assigned to department Assembly, shift Afternoon, on Sat
# Worker 76 assigned to department Assembly, shift Night, on Fri
# Worker 76 assigned to department Paint, shift Afternoon, on Thur
# Worker 77 assigned to department Paint, shift Morning, on Tue
# Worker 77 assigned to department Paint, shift Morning, on Wed
# Worker 77 assigned to department Paint, shift Afternoon, on Thur
# Worker 77 assigned to department Paint, shift Afternoon, on Sat
# Worker 77 assigned to department Paint, shift Night, on Mon
# Worker 78 assigned to department Battery, shift Morning, on Wed
# Worker 78 assigned to department Battery, shift Afternoon, on Thur
# Worker 78 assigned to department Battery, shift Night, on Sun
# Worker 78 assigned to department Body, shift Night, on Tue
# Worker 78 assigned to department Paint, shift Morning, on Sat
# Worker 79 assigned to department Battery, shift Afternoon, on Sat
# Worker 79 assigned to department Body, shift Afternoon, on Mon
# Worker 79 assigned to department Body, shift Night, on Sun
# Worker 79 assigned to department Paint, shift Afternoon, on Fri
# Worker 79 assigned to department Quality, shift Afternoon, on Thur
# Worker 80 assigned to department Battery, shift Afternoon, on Wed
# Worker 80 assigned to department Body, shift Morning, on Mon
# Worker 80 assigned to department Body, shift Night, on Sat
# Worker 80 assigned to department Assembly, shift Afternoon, on Fri
# Worker 80 assigned to department Paint, shift Morning, on Sun
# Worker 81 assigned to department Battery, shift Afternoon, on Wed
# Worker 81 assigned to department Body, shift Afternoon, on Thur
# Worker 81 assigned to department Paint, shift Morning, on Mon
# Worker 81 assigned to department Paint, shift Afternoon, on Sun
# Worker 81 assigned to department Quality, shift Morning, on Tue
# Worker 82 assigned to department Battery, shift Morning, on Thur
# Worker 82 assigned to department Body, shift Afternoon, on Mon
# Worker 82 assigned to department Body, shift Afternoon, on Sat
# Worker 82 assigned to department Assembly, shift Night, on Tue
# Worker 82 assigned to department Paint, shift Afternoon, on Wed
# Worker 83 assigned to department Paint, shift Morning, on Sat
# Worker 83 assigned to department Paint, shift Afternoon, on Sun
# Worker 83 assigned to department Paint, shift Night, on Fri
# Worker 83 assigned to department Quality, shift Morning, on Tue
# Worker 83 assigned to department Quality, shift Night, on Wed
# Worker 84 assigned to department Battery, shift Night, on Wed
# Worker 84 assigned to department Body, shift Afternoon, on Sun
# Worker 84 assigned to department Assembly, shift Night, on Fri
# Worker 84 assigned to department Paint, shift Morning, on Mon
# Worker 84 assigned to department Quality, shift Morning, on Thur
# Worker 85 assigned to department Body, shift Morning, on Thur
# Worker 85 assigned to department Body, shift Night, on Wed
# Worker 85 assigned to department Paint, shift Afternoon, on Mon
# Worker 85 assigned to department Paint, shift Night, on Tue
# Worker 85 assigned to department Paint, shift Night, on Sun
# Worker 86 assigned to department Battery, shift Night, on Sun
# Worker 86 assigned to department Body, shift Morning, on Thur
# Worker 86 assigned to department Assembly, shift Morning, on Wed
# Worker 86 assigned to department Quality, shift Morning, on Tue
# Worker 86 assigned to department Quality, shift Night, on Sat
# Worker 87 assigned to department Body, shift Morning, on Mon
# Worker 87 assigned to department Body, shift Night, on Tue
# Worker 87 assigned to department Assembly, shift Afternoon, on Wed
# Worker 87 assigned to department Assembly, shift Night, on Sun
# Worker 87 assigned to department Paint, shift Afternoon, on Thur
# Worker 88 assigned to department Battery, shift Morning, on Sun
# Worker 88 assigned to department Assembly, shift Morning, on Sat
# Worker 88 assigned to department Assembly, shift Afternoon, on Wed
# Worker 88 assigned to department Paint, shift Night, on Tue
# Worker 88 assigned to department Quality, shift Morning, on Thur
# Worker 89 assigned to department Body, shift Morning, on Mon
# Worker 89 assigned to department Body, shift Morning, on Fri
# Worker 89 assigned to department Body, shift Night, on Sat
# Worker 89 assigned to department Body, shift Night, on Sun
# Worker 89 assigned to department Paint, shift Morning, on Thur
# Worker 90 assigned to department Battery, shift Afternoon, on Tue
# Worker 90 assigned to department Body, shift Night, on Sat
# Worker 90 assigned to department Assembly, shift Morning, on Mon
# Worker 90 assigned to department Assembly, shift Afternoon, on Fri
# Worker 90 assigned to department Paint, shift Morning, on Thur
# Worker 91 assigned to department Battery, shift Afternoon, on Tue
# Worker 91 assigned to department Assembly, shift Night, on Mon
# Worker 91 assigned to department Assembly, shift Night, on Sun
# Worker 91 assigned to department Quality, shift Afternoon, on Sat
# Worker 91 assigned to department Quality, shift Night, on Thur
# Worker 92 assigned to department Battery, shift Night, on Thur
# Worker 92 assigned to department Battery, shift Night, on Sat
# Worker 92 assigned to department Assembly, shift Morning, on Tue
# Worker 92 assigned to department Paint, shift Morning, on Wed
# Worker 92 assigned to department Paint, shift Afternoon, on Sun
# Worker 93 assigned to department Body, shift Afternoon, on Sun
# Worker 93 assigned to department Assembly, shift Morning, on Wed
# Worker 93 assigned to department Quality, shift Morning, on Sat
# Worker 93 assigned to department Quality, shift Afternoon, on Tue
# Worker 93 assigned to department Quality, shift Night, on Fri
# Worker 94 assigned to department Battery, shift Afternoon, on Mon
# Worker 94 assigned to department Body, shift Morning, on Sat
# Worker 94 assigned to department Paint, shift Morning, on Tue
# Worker 94 assigned to department Paint, shift Morning, on Thur
# Worker 94 assigned to department Paint, shift Night, on Sun
# Worker 95 assigned to department Battery, shift Night, on Mon
# Worker 95 assigned to department Body, shift Morning, on Thur
# Worker 95 assigned to department Body, shift Afternoon, on Sun
# Worker 95 assigned to department Assembly, shift Night, on Tue
# Worker 95 assigned to department Paint, shift Afternoon, on Sat
# Worker 96 assigned to department Body, shift Morning, on Sun
# Worker 96 assigned to department Body, shift Afternoon, on Wed
# Worker 96 assigned to department Quality, shift Morning, on Thur
# Worker 96 assigned to department Quality, shift Afternoon, on Tue
# Worker 96 assigned to department Quality, shift Afternoon, on Fri
# Worker 97 assigned to department Battery, shift Afternoon, on Fri
# Worker 97 assigned to department Assembly, shift Morning, on Mon
# Worker 97 assigned to department Assembly, shift Night, on Wed
# Worker 97 assigned to department Assembly, shift Night, on Sun
# Worker 97 assigned to department Paint, shift Night, on Tue
# Worker 98 assigned to department Battery, shift Afternoon, on Sat
# Worker 98 assigned to department Body, shift Afternoon, on Tue
# Worker 98 assigned to department Assembly, shift Afternoon, on Mon
# Worker 98 assigned to department Assembly, shift Night, on Sun
# Worker 98 assigned to department Quality, shift Night, on Wed
# Worker 99 assigned to department Body, shift Morning, on Mon
# Worker 99 assigned to department Body, shift Morning, on Wed
# Worker 99 assigned to department Body, shift Night, on Sun
# Worker 99 assigned to department Quality, shift Morning, on Thur
# Worker 99 assigned to department Quality, shift Night, on Sat
# Worker 100 assigned to department Battery, shift Morning, on Thur
# Worker 100 assigned to department Body, shift Morning, on Fri
# Worker 100 assigned to department Body, shift Night, on Tue
# Worker 100 assigned to department Body, shift Night, on Wed
# Worker 100 assigned to department Assembly, shift Afternoon, on Mon

# %%
## Question 3

# %%
from gurobipy import Model, GRB

m = Model("IP")

x1 = m.addVar(vtype=GRB.CONTINUOUS, name="x1")
x2 = m.addVar(vtype=GRB.CONTINUOUS, name="x2")

m.setObjective(4 * x1 - x2, GRB.MAXIMIZE)

m.addConstr(7 * x1 - 2 * x2 <= 14, "c1")  
m.addConstr(x2 <= 3, "c2")                
m.addConstr(2 * x1 - 2 * x2 <= 3, "c3")   

m.addConstr(x1 <= 2, "branch")
m.addConstr(x2 >= 1, "branch1")

m.optimize()

if m.status == GRB.OPTIMAL:
    print(f"Optimal solution found:")
    print(f"x1 = {x1.x}")
    print(f"x2 = {x2.x}")
    print(f"Objective value (z) = {m.objVal}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 23.4.0 23E224)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 5 rows, 2 columns and 7 nonzeros
# Model fingerprint: 0x68e4634b
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 5 rows and 2 columns
# Presolve time: 0.11s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.24 seconds (0.00 work units)
# Optimal objective  7.000000000e+00
# Optimal solution found:
# x1 = 2.0
# x2 = 1.0
# Objective value (z) = 7.0
